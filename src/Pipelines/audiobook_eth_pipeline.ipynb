# %% [markdown]
# We go from processing the srt by concatenating with embedded timestamp [] text and chunk using keyword "Chapter #integer based english word#, "

# %%
import re
class SRTItem:
    def __init__(self, index, text):
        self.index = index
        self.text = text
    def __repr__(self):
        return f"SRTItem(index={self.index}, text={self.text})"
    def __str__(self):
        return f"{self.index}\n{self.text}"
    
def process_srt(srt_file):
    """
    Processes an SRT string to embed the start timestamp at the beginning
    of its corresponding text lines.

    Args:
        srt_content: A string containing the content of an SRT file.

    Returns:
        A string with the modified SRT content, or an empty string
        if the input is invalid or empty.
        Returns the original content if no valid SRT blocks are found.
    """
    with open(srt_file, 'r', encoding='utf-8') as file:
        content = file.read()
    if not content.strip():
        print("There is no content in the SRT")
        return ""
    # Split the content into individual subtitles
    subtitles = [block.strip() for block in re.split(r'\n\s*\n', content.strip())]

    modified_blocks = []
    processed_indicies = set()
    for block in subtitles:
        lines = block.splitlines()
        # Handling invalid blocks
        if len(lines) < 3:
            modified_blocks.append(block)
            continue
        try:
            ### index
            ### timestamp [00:00:13,666 --> 00:00:15,427]
            ### content 
            index_str = lines[0].strip() # timestamp
            index = int(index_str)
            if index in processed_indicies:
                modified_blocks.append(block)
                continue
            processed_indicies.add(index)
            
            # --timestamp--
            timestamp_line = lines[1].strip()
            match = re.match(r'(\d{2}:\d{2}:\d{2},\d{3})\s*-->\s*(\d{2}:\d{2}:\d{2},\d{3})', timestamp_line)
            start_timestamp = match.group(1)
            end_timestamp = match.group(2)
            text_lines = lines[2:]
            if not text_lines:
                modified_blocks.append(block)
                continue
            modified_first_text_line = f"[{start_timestamp},{end_timestamp}] {text_lines[0]}"
            modified_text_lines = [modified_first_text_line] + text_lines[1:]

            modified_block = SRTItem(index, "\n".join(modified_text_lines))
            modified_blocks.append(modified_block)
            
        except (ValueError, IndexError) as e:
            modified_blocks.append(block)

    return modified_blocks

# processed_srt_str =(process_srt(r"D:\DATA300\AudioBookSum\data\AtomicHabit\transcribed (2).srt"))
# print(processed_srt_str)

# %%
import re

def text2int(textnum, numwords={}):
    if not numwords:
      units = [
        "zero", "one", "two", "three", "four", "five", "six", "seven", "eight",
        "nine", "ten", "eleven", "twelve", "thirteen", "fourteen", "fifteen",
        "sixteen", "seventeen", "eighteen", "nineteen",
      ]

      tens = ["", "", "twenty", "thirty", "forty", "fifty", "sixty", "seventy", "eighty", "ninety"]

      scales = ["hundred", "thousand", "million", "billion", "trillion"]

      numwords["and"] = (1, 0)
      for idx, word in enumerate(units):    numwords[word] = (1, idx)
      for idx, word in enumerate(tens):     numwords[word] = (1, idx * 10)
      for idx, word in enumerate(scales):   numwords[word] = (10 ** (idx * 3 or 2), 0)

    current = result = 0
    for word in textnum.split():
        try:
            if word not in numwords:
                raise Exception("Illegal word: " + word)

            scale, increment = numwords[word]
            current = current * scale + increment
            if scale > 100:
                result += current
                current = 0
        except Exception as e:
            print(e)
            return None
    return result + current
def int2text(num):
    if num == 0:
        return "Zero"
    
    bigString = ["Thousand", "Million", "Billion"]
    result = numberToWordsHelper(num % 1000)
    num //= 1000
    
    for i in range(len(bigString)):
        if num > 0 and num % 1000 > 0:
            result = numberToWordsHelper(num % 1000) + bigString[i] + " " + result
        num //= 1000
    
    return result.strip()

def numberToWordsHelper(num: int) -> str:
    digitString = ["Zero", "One", "Two", "Three", "Four", "Five", "Six", "Seven", "Eight", "Nine"]
    teenString = ["Ten", "Eleven", "Twelve", "Thirteen", "Fourteen", "Fifteen", "Sixteen", "Seventeen", "Eighteen", "Nineteen"]
    tenString = ["", "", "Twenty", "Thirty", "Forty", "Fifty", "Sixty", "Seventy", "Eighty", "Ninety"]
    
    result = ""
    if num > 99:
        result += digitString[num // 100] + " Hundred "
    
    num %= 100
    if num < 20 and num > 9:
        result += teenString[num - 10] + " "
    else:
        if num >= 20:
            result += tenString[num // 10] + " "
        num %= 10
        if num > 0:
            result += digitString[num] + " "
    
    return result

NUM_WORDS = [int2text(i).lower() for i in range(1,100)]
chapter_pattern_text_based_rg = r'Chapter\s+(?:' + '|'.join(NUM_WORDS) + r')\b[\s:.]*'
chapter_pattern_int_based_rg = r'Chapter\s+\d+\b[\s:.]*'
chapter_pattern_text = re.compile(chapter_pattern_text_based_rg, re.IGNORECASE)
chapter_pattern_int = re.compile(chapter_pattern_int_based_rg, re.IGNORECASE)

# %%
# In cell with id 'c8ce6d60'
from typing import List
# Remove RecursiveCharacterTextSplitter import if no longer needed here
# from langchain.text_splitter import RecursiveCharacterTextSplitter
import re # Add import for re

# Assumes SRTItem class is defined in a previous cell
# Assumes chapter_pattern_text, chapter_pattern_int are defined in a previous cell
# Assumes timestamp_pattern is defined in a previous cell (e.g., cell 'ebac4212')

class ChunkedSRTItem:
    def __init__(self, start_index, end_index, chunk: List[SRTItem]): # Ensure chunk type hint is List[SRTItem]
        self.start_index = start_index
        self.end_index = end_index
        self.chunk = chunk if chunk else []

    def __repr__(self):
        return f"ChunkedSRTItem(start={self.start_index}, end={self.end_index}, items={len(self.chunk)})"

# Helper function to get text after timestamp pattern
def _get_text_after_timestamp(text: str, pattern: re.Pattern) -> str:
    """Extracts text content after the initial timestamp pattern."""
    if not text or not pattern:
        return text.strip() if text else ""
    match = pattern.match(text)
    return text[match.end():].strip() if match else text.strip()

def chunking_srt_by_chapter(
    srt_items: List[SRTItem],
    chapter_pattern_text: re.Pattern,
    chapter_pattern_int: re.Pattern,
    timestamp_pattern: re.Pattern # Pass the compiled pattern
) -> List[ChunkedSRTItem]:
    """
    Chunks a list of SRTItem objects based on chapter markers found in the text.
    Each chunk starts with an SRTItem whose text begins with a timestamp annotation '[start,end]'.

    Args:
        srt_items: List of SRTItem objects from process_srt.
        chapter_pattern_text: Compiled regex for text-based chapter markers.
        chapter_pattern_int: Compiled regex for integer-based chapter markers.
        timestamp_pattern: Compiled regex for the timestamp pattern '[start,end]'.

    Returns:
        A list of ChunkedSRTItem objects, where each object's 'chunk' attribute
        is a list of SRTItems belonging to that chapter/segment.
    """
    if not srt_items:
        print("Warning: chunking_srt_by_chapter received empty srt_items list.")
        return []

    # Ensure patterns are compiled regex objects
    if not isinstance(chapter_pattern_text, re.Pattern) or \
       not isinstance(chapter_pattern_int, re.Pattern) or \
       not isinstance(timestamp_pattern, re.Pattern):
        print("Error: Chapter or timestamp patterns are not compiled regex objects.")
        # Potentially raise an error or return empty list
        return []

    chunk_data_by_chapter: List[ChunkedSRTItem] = []
    current_chunk_items: List[SRTItem] = []

    for item in srt_items:
        # Basic validation of the item structure
        if not isinstance(item, SRTItem) or not hasattr(item, 'text') or not hasattr(item, 'index'):
             print(f"Warning: Skipping invalid item in srt_items: {item}")
             continue
        # Ensure text is a string
        if not isinstance(item.text, str):
            print(f"Warning: Skipping item with non-string text (Index: {item.index}): {type(item.text)}")
            continue

        text_after_ts = _get_text_after_timestamp(item.text, timestamp_pattern)

        # Check if the text (after potential timestamp) contains a chapter marker
        is_chapter_start = False
        if text_after_ts: # Only search if there's text after the timestamp
             is_chapter_start = bool(chapter_pattern_text.search(text_after_ts) or \
                                     chapter_pattern_int.search(text_after_ts))

        if is_chapter_start and current_chunk_items:
            # Finalize the previous chunk if it's not empty
            chunk_data_by_chapter.append(ChunkedSRTItem(
                start_index=current_chunk_items[0].index,
                end_index=current_chunk_items[-1].index,
                chunk=current_chunk_items
            ))
            # Start new chunk with the chapter item
            current_chunk_items = [item]
        else:
            # Add item to the current chunk
            current_chunk_items.append(item)

    # Add the last chunk if it exists and is not empty
    if current_chunk_items:
        chunk_data_by_chapter.append(ChunkedSRTItem(
            start_index=current_chunk_items[0].index,
            end_index=current_chunk_items[-1].index,
            chunk=current_chunk_items
        ))

    print(f"Chunking complete. Generated {len(chunk_data_by_chapter)} chapter-based chunks.")
    return chunk_data_by_chapter

# Example usage within this cell (if any) should be updated:
# Replace the line:
# len(chunking_srt(processed_srt_str))
# With:
# Assuming processed_srt_str, chapter_pattern_text, chapter_pattern_int, timestamp_pattern exist
timestamp_re_str = r'\s*\[\s*(\d{2}:\d{2}:\d{2},\d{3})\s*,\s*(\d{2}:\d{2}:\d{2},\d{3})\s*\]\s*'
timestamp_pattern = re.compile(timestamp_re_str)
# chapter_chunks = chunking_srt_by_chapter(processed_srt_str, chapter_pattern_text, chapter_pattern_int, timestamp_pattern)
# # print(f"Number of chapter chunks: {len(chapter_chunks)}")
# # if chapter_chunks:
# #     print(f"First chunk details: {chapter_chunks[0]}")
# print(chapter_chunks)

# %% [markdown]
# We then run the chapter-based chunks through an llm with a structured output

# %%
# In cell with id 'ebac4212'
import datetime
import os
import json
import re
import difflib
from collections import defaultdict
from dotenv import load_dotenv
from typing import List, Dict, Any, Tuple, Optional, DefaultDict, Type

from pydantic import BaseModel, Field

# Assuming SRTItem and ChunkedSRTItem classes are defined in previous cells
# from <previous_cell_module> import SRTItem, ChunkedSRTItem # Or ensure they are defined above

try:
    from langchain_google_genai import ChatGoogleGenerativeAI
    LLMClientType = ChatGoogleGenerativeAI
except ImportError:
    print("Warning: langchain-google-genai not found. Using 'Any' for LLM type hint.")
    print("Please install it: pip install langchain-google-genai")
    LLMClientType = Any

load_dotenv()

class EvidenceSnippet(BaseModel):
    """Represents a single verbatim evidence snippet."""
    verbatim_text: str = Field(..., description="The exact verbatim text snippet extracted from the document, including any '[]' annotation if present at the beginning of the snippet.")

class SummaryAndEvidence(BaseModel):
    """Schema for the desired LLM output containing summary and evidence."""
    summary: str = Field(..., description="A concise summary based solely on the provided document content.")
    evidence: List[EvidenceSnippet] = Field(..., description="A list of verbatim evidence snippets supporting the key points of the summary.")

# Regex to find and capture the [start,end] annotation at the beginning of a string
# Allows for whitespace variations
timestamp_re_str = r'\s*\[\s*(\d{2}:\d{2}:\d{2},\d{3})\s*,\s*(\d{2}:\d{2}:\d{2},\d{3})\s*\]\s*'
timestamp_pattern = re.compile(timestamp_re_str)


def proper_extract(raw_snippet_text: str) -> Tuple[str, Optional[Tuple[str, str]]]:
    """
    Cleans the raw snippet text from the LLM.
    Removes the leading '[start,end]' annotation if present.
    Returns the cleaned text and the extracted timestamp tuple (or None).
    """
    match = timestamp_pattern.match(raw_snippet_text)
    if match:
        # Extract the timestamp tuple ('start', 'end')
        extracted_ts = (match.group(1), match.group(2)) # Correctly capture both groups
        cleaned_text = raw_snippet_text[match.end():].strip()
        return cleaned_text, extracted_ts
    else:
        return raw_snippet_text.strip(), None

def _find_matching_block(
    segment_text: str,
    original_material: List[SRTItem], # List of parsed ORIGINAL SRT dicts
    min_similarity_threshold: float = 0.4 # Threshold for considering a match
) -> Tuple[Optional[Dict[str, Any]], float]:
    """
    Finds the best matching text block in the *original* parsed SRT data for a given segment text
    using similarity matching. Matches against the 'text' field in original_material.
    """
    norm_segment = ' '.join(segment_text.split())
    if not norm_segment:
        return None, 0.0

    best_match_block: Optional[Dict[str, Any]] = None
    highest_similarity: float = 0.0

    for block in original_material:
        # Ensure 'text' key exists and is a non-empty string
        # Use the ORIGINAL text for matching
        block_text = block.text if isinstance(block, SRTItem) else block.get("text", "")
        if not isinstance(block_text, str) or not block_text:
            continue
        block_text, timestamp = proper_extract(block_text)
        norm_block_text = ' '.join(block_text.split())
        if not norm_block_text:
             continue
        
        # Use SequenceMatcher for similarity calculation.
        # autojunk=False can be important for short strings or repetitive text.
        matcher = difflib.SequenceMatcher(None, norm_segment, norm_block_text, autojunk=False)
        similarity = matcher.ratio()
        # print(f"Comparing segment: '{norm_segment[:50]}...' with block: '{norm_block_text[:50]}...' - Similarity: {similarity:.4f}")
        if similarity > highest_similarity:
            highest_similarity = similarity
            best_match_block = block
        if similarity == 1:
            break
    if best_match_block and highest_similarity >= min_similarity_threshold:
        return best_match_block, highest_similarity

    return None, 0.0


def _process_segment(
    raw_snippet_text: str,
    index_hint: Optional[Tuple[int, int]], # Optional index hint for the segment
    original_material: List[Dict[str, Any]], # This is the list of ORIGINAL parsed SRT dicts
    min_word_threshold: int
) -> Optional[Dict[str, Any]]:
    """
    Processes a raw evidence snippet text provided by the LLM.
    1. Cleans the snippet (removes potential leading '[start,end]' annotation).
    2. Finds the best matching block in the original parsed SRT data using the cleaned text.
    3. Returns a dictionary with the matched block's actual timestamp tuple
       and the *cleaned* text content from the snippet.
    """
    cleaned_text, _ = proper_extract(raw_snippet_text)

    if not cleaned_text or len(cleaned_text.split()) < min_word_threshold:
        return None
    search_perimeter = original_material if not index_hint else original_material[index_hint[0]-1:index_hint[1]-1]
    # print(index_hint)
    # Step 2: Find the best matching block in the original data
    matched_block, match_similarity = _find_matching_block(
        cleaned_text, search_perimeter 
    )

    if matched_block:
        actual_timestamp_tuple = extract_timestamp_from_text(matched_block.text)
        if not actual_timestamp_tuple or not (isinstance(actual_timestamp_tuple, tuple) and len(actual_timestamp_tuple) == 2):
             print(f"Warning: Matched block (Index: {matched_block.index}) has missing or invalid timestamp: {actual_timestamp_tuple}. Skipping snippet.")
             return None

        # Return the actual timestamp from the matched block and the cleaned text from the LLM snippet
        return {
            "timestamp": actual_timestamp_tuple, 
            "text": cleaned_text, 
            "match_score": match_similarity,
            "matched_index": matched_block.index
        }
    else:
        print(f"Warning: No matching block found (score < threshold) for snippet: '{raw_snippet_text}...' (Cleaned: '{cleaned_text}...')")
        return None

def extract_timestamp_from_text(text: str) -> Optional[Tuple[str, str]]:
    """
    Extracts the timestamp tuple from the beginning of a text snippet.
    Returns a tuple (start, end) if found, otherwise None.
    """
    match = timestamp_pattern.match(text)
    if match:
        return match.groups()
    return None


def identify_interesting_points_structured(
    chunked_data: List[ChunkedSRTItem],
    llm: LLMClientType,
    output_schema: Type[BaseModel],
    original_data: List[SRTItem],
    min_snippet_word_count: int = 5,
    cache_file_path: str = "summary_evidence_cache.json", # Path to cache file
    is_one_p: bool = True # Flag to process all chunks in one prompt
) -> Tuple[Optional[str], List[Dict[str, Any]]]:
    """
    Identifies summary and evidence snippets using an LLM with structured output.

    Args:
        chunked_data: List of ChunkedSRTItem objects from chunking_srt_by_chapter.
        llm: Initialized LLM client supporting structured output.
        output_schema: The Pydantic BaseModel class (e.g., SummaryAndEvidence).
        original_data: The list of original parsed SRT block dictionaries (before timestamp prefixing).
        cache_file_name: Path to the JSON file for caching LLM results.
        min_snippet_word_count: Minimum word count for a processed evidence snippet.
        is_one_p: If True, concatenates all chunks into one LLM prompt.
                  If False, processes chunks sequentially (requires careful implementation).

    Returns:
        A tuple containing:
        - The generated summary string (or None).
        - A list of processed evidence snippet dictionaries [{'timestamp': (start, end), 'text': ...}].
    """
    summary_result: Optional[str] = None
    processed_segments: List[Dict[str, Any]] = []

    if not chunked_data:
        print("Warning: No chunked data provided.")
        return None, []

    # Input validation for original_data
    if not isinstance(original_data, list) or (original_data and not isinstance(original_data[0], SRTItem)):
         print("Error: `original_data` must be a list of dictionaries (parsed original SRT data).")
         return None, []
    

    cache_dir = os.path.dirname(cache_file_path)
    cache_base_name = os.path.basename(cache_file_path).split('.')[0]
    chunks_dir = os.path.join(cache_dir, f"{cache_base_name}_chunks")
    master_cache_path = os.path.join(cache_dir, f"{cache_base_name}_master.json")
    
    # Create cache directories if they don't exist
    os.makedirs(chunks_dir, exist_ok=True)
    
    # Cache Handling
    cache_loaded = False

    if os.path.exists(master_cache_path):
        try:
            # logger.info(f"Loading master cache index from {master_cache_path}")
            with open(master_cache_path, "r", encoding="utf-8") as f:
                master_cache = json.load(f)
            summary_result = master_cache.get("summary", "")
            chunk_files = master_cache.get("chunk_files", [])
            
            # Load all chunk files
            raw_cached_snippets = dict()
            for chunk_file in chunk_files:
                chunk_path = os.path.join(chunks_dir, chunk_file)
                if os.path.exists(chunk_path):
                    try:
                        with open(chunk_path, "r", encoding="utf-8") as f:
                            chunk_data = json.load(f)
                            chunk_evidence = [snippet["verbatim_text"] for snippet in chunk_data.get("evidence", [])]
                            
                            raw_cached_snippets[(chunk_data.get("start_index",-1), chunk_data.get("end_index",-1))] = chunk_evidence
                    except Exception as e:
                        # logger.warning(f"Error loading chunk file {chunk_path}: {str(e)}")
                        print(f"Error loading chunk file {chunk_path}: {str(e)}")
            # print(raw_cached_snippets)
            temp_processed_segments = []
            for start_idx, end_idx in raw_cached_snippets.keys():
                for i in raw_cached_snippets[(start_idx, end_idx)]:
                    snippet_text = i
                    possible_idx_range = (start_idx, end_idx) if start_idx != -1 and end_idx != -1 else None
                    processed = _process_segment(snippet_text, possible_idx_range, original_data, min_snippet_word_count)
                    if processed:
                        temp_processed_segments.append(processed)

            processed_segments = temp_processed_segments

            if summary_result or processed_segments:
                # logger.info(f"Cache loaded and validated: Summary: {summary_result is not None}, Snippets: {len(processed_segments)}")
                cache_loaded = True
            else:
                # logger.warning("Cache files loaded but resulted in no valid data after processing. Will regenerate.")
                print("Cache files loaded but resulted in no valid data after processing. Will regenerate.")
        except json.JSONDecodeError:
            # logger.error(f"Error decoding JSON from master cache file {master_cache_path}")
            print(f"Error decoding JSON from master cache file {master_cache_path}. Will regenerate cache.")
        except Exception as e: 
            print(f"Error loading cache files: {e}")
            # logger.error(f"Error loading cache files: {str(e)}")
    if not cache_loaded:
        print("Generating new summary and evidence points using LLM with structured output...")
        chunk_files = []  # List to store chunk file names
        prompt_template_str = os.getenv("SUMMARY_EVIDENCE_PROMPT_STRUCTURED_AB")
        if not prompt_template_str:
            print("Error: Environment variable 'SUMMARY_EVIDENCE_PROMPT_STRUCTURED_AB' not set.")
            return None, []
        verbatim_result_to_chunk_mapping = defaultdict(list) # For mapping verbatim results to chunk indices 
        try:
            response_object = SummaryAndEvidence(summary="", evidence=[])
            if is_one_p:
                all_text_for_llm = "\n\n".join([
                    "\n".join([srt_item.text for srt_item in chunked_srt.chunk])
                    for chunked_srt in chunked_data if chunked_srt.chunk 
                ]).strip()


                if not all_text_for_llm:
                    print("Error: No text content found in chunked_data to send to LLM.")
                    return None, []

                final_prompt = prompt_template_str + "\n\nDocument Content:\n" + all_text_for_llm

                try:
                    structured_llm = llm.with_structured_output(output_schema)
                    print("LLM configured for structured output.")
                except AttributeError:
                    print(f"Error: The provided LLM client object (type: {type(llm)}) does not appear to have a '.with_structured_output' method.")
                    return None, []
                except Exception as e:
                    print(f"Error configuring LLM for structured output: {e}")
                    return None, []

                # logger.info("Sending request to LLM for structured response")
                response: SummaryAndEvidence = structured_llm.invoke(final_prompt)
                # logger.info("Structured response received from LLM")
                
                response_object.summary = response.summary.strip()
                response_object.evidence.extend(response.evidence)
                
                # Save the single chunk
                chunk_filename = f"chunk_all.json"
                chunk_path = os.path.join(chunks_dir, chunk_filename)
                try:
                    with open(chunk_path, "w", encoding="utf-8") as f:
                        json.dump(response.model_dump(), f, ensure_ascii=False, indent=2)
                    chunk_files.append(chunk_filename)
                    # logger.info(f"Saved chunk to {chunk_path}")
                except Exception as e:
                    print(f"Error saving chunk file {chunk_path}: {e}")
                    # logger.error(f"Error saving chunk file {chunk_path}: {str(e)}")

            else:
                chunk_files = []  # List to store chunk file names
                for chunk_idx, chunk in enumerate(chunked_data):
                    if not chunk.chunk: continue
                    chunk_text = "\n".join([item.text for item in chunk.chunk]).strip()
                    if not chunk_text: continue

                    print(f"Processing chunk {chunk_idx+1}...")
                    chunk_prompt = prompt_template_str + "\n\nDocument Content:\n" + chunk_text
                    if response_object.summary:
                        chunk_prompt += f"\n\nCurrent Summary:\n{response_object.summary.strip()}"
                    try:
                        structured_llm = llm.with_structured_output(output_schema)
                        chunk_response: SummaryAndEvidence = structured_llm.invoke(chunk_prompt)
                        response_object.summary += chunk_response.summary.strip() + "\n"
                        verbatim_result_to_chunk_mapping[(len(response_object.evidence),len(response_object.evidence) + len(chunk_response.evidence))] = (chunk.start_index, chunk.end_index)  # Store chunk index for each evidence snippet
                        response_object.evidence.extend(chunk_response.evidence)
                        
                        # Save each chunk separately
                        chunk_filename = f"chunk_{chunk_idx:03d}.json"
                        chunk_response_json = chunk_response.model_dump()
                        chunk_response_json["start_index"] = chunk.start_index
                        chunk_response_json["end_index"] = chunk.end_index 
                        chunk_path = os.path.join(chunks_dir, chunk_filename)
                        with open(chunk_path, "w", encoding="utf-8") as f:
                            json.dump(chunk_response_json, f, ensure_ascii=False, indent=2)
                        print(f"Saved chunk {chunk_idx+1} to {chunk_path}")
                        chunk_files.append(chunk_filename)
                    except Exception as e:
                        print(f"Error processing chunk {chunk_idx+1}: {e}")

            # --- Process LLM response (common for is_one_p=True or after aggregation) ---
            summary_result = response_object.summary
            raw_snippet_objects = response_object.evidence
            raw_snippets_text = [snippet.verbatim_text for snippet in raw_snippet_objects]

            print(f"Extracted Summary: {summary_result is not None}. Extracted Raw Snippets: {len(raw_snippets_text)}")

            processed_segments = []

            print(f"Processing {len(raw_snippets_text)} raw snippets...")
            most_right = 0
            chunks_indexes = []
            curr_chunk = 0
            """
                if i <= most_right:
                    index_hint = chunking_section[curr]
                else:
                    curr += 1
                    most_right = chunking_section[curr][1] if curr < len(chunking_section) else 0
                    index_hint = chunking_section[curr]
                print(f"Processing snippet {i+1} with index hint: {index_hint}")
            """
            if not is_one_p:
                chunks_indexes = [(chunk.start_index, chunk.end_index) for chunk in chunked_data if chunk.chunk]
                most_right = chunks_indexes[curr_chunk][1] if chunks_indexes else 0 
            for i, snippet_text in enumerate(raw_snippets_text):
                index_hint = None
                if not is_one_p:
                    if i <= most_right:
                        index_hint = verbatim_result_to_chunk_mapping.get(chunks_indexes[curr_chunk], None)
                    else:
                        curr_chunk += 1
                        most_right = chunks_indexes[curr_chunk][1] if curr_chunk < len(chunks_indexes) else 0
                        index_hint = verbatim_result_to_chunk_mapping.get(chunks_indexes[curr_chunk], None)
                processed_section = _process_segment(snippet_text,index_hint if most_right > 0 else None, original_data,
                    min_snippet_word_count)
                    
                if processed_section:
                    processed_segments.append(processed_section)
            try:
                master_cache = {
                    "summary": summary_result,
                    "chunk_files": chunk_files,
                    "total_evidence_count": len(raw_snippets_text),
                    "timestamp": str(datetime.datetime.now())
                }
                
                with open(master_cache_path, "w", encoding="utf-8") as f:
                    json.dump(master_cache, f, ensure_ascii=False, indent=2)
                # logger.info(f"Saved master cache index to {master_cache_path}")
            except Exception as e:
                print(f"Error saving master cache file {master_cache_path}: {e}")
                # logger.error(f"Error saving master cache file {master_cache_path}: {str(e)}")
        except Exception as e:
            # logger.error(f"Error during LLM interaction: {str(e)}")
            import traceback
            # logger.error(traceback.format_exc())
            print(f"Error during LLM interaction: {e}")
            summary_result = None
            processed_segments = []

    valid_segments = [
        seg for seg in processed_segments
        if isinstance(seg, dict) and isinstance(seg.get("timestamp"), tuple) and len(seg["timestamp"]) == 2 and isinstance(seg.get("text"), str)
    ]
    if len(valid_segments) != len(processed_segments):
        print(f"Warning: Filtered out {len(processed_segments) - len(valid_segments)} invalid segment structures before returning.")
        processed_segments = valid_segments


    return summary_result, processed_segments


# --- Example Call Setup ---
# Define file paths (ensure these are correct)
original_srt_filepath = r"D:\DATA300\AudioBookSum\data\AtomicHabit\transcribed (2).srt"
notebook_dir = os.path.dirname(os.path.abspath("__file__")) if "__file__" in locals() else os.getcwd() # Get notebook dir
cache_dir = os.path.join(notebook_dir, "cache")
os.makedirs(cache_dir, exist_ok=True) # Ensure cache directory exists

srt_basename = os.path.basename(original_srt_filepath)
srt_name_no_ext = os.path.splitext(srt_basename)[0]
cache_filename = f"{srt_name_no_ext}_summary_evidence_cache.json"
cache_filepath = os.path.join(cache_dir, cache_filename)

# Initialize LLM (ensure API key is set in .env or environment)
try:
    # Make sure GOOGLE_API_KEY is set in your environment or .env file
    llm = ChatGoogleGenerativeAI(model='gemini-2.0-flash', temperature=0.7) # Use a known valid model
    print("LLM Initialized.")
except Exception as e:
    print(f"Error initializing LLM: {e}")
    print("Ensure GOOGLE_API_KEY is set and the model name is correct.")
    llm = None

processed_srt_str = process_srt(original_srt_filepath)

# --- Data Preparation ---
# 1. Process SRT to add timestamps (assuming processed_srt_str is from cell 2a36cdbf)
# processed_srt_str should be List[SRTItem]
if 'processed_srt_str' not in locals() or not isinstance(processed_srt_str, list):
     print("Error: 'processed_srt_str' (List[SRTItem]) not found or is not a list. Please run the cell '2a36cdbf'.")
     processed_srt_str = [] # Avoid crashing later calls

# 2. Parse the ORIGINAL SRT file to get data for matching
#    (This is crucial for _process_segment to find correct timestamps)
original_parsed_srt_data = process_srt(original_srt_filepath)
original_parsed_srt_data.sort(key=lambda x: x.index)
if not original_parsed_srt_data:
    print("Warning: Could not parse original SRT data. Snippet matching might fail.")

# 3. Define chapter patterns (assuming they are defined in cell c2211bc8)
if 'chapter_pattern_text' not in locals() or 'chapter_pattern_int' not in locals():
    print("Error: Chapter patterns not defined. Please run cell 'c2211bc8'.")
    # Define dummy patterns to avoid crashing, but this won't work correctly
    chapter_pattern_text = re.compile(r"dummy_chapter_text_pattern_never_match")
    chapter_pattern_int = re.compile(r"dummy_chapter_int_pattern_never_match")

# 4. Define timestamp pattern (defined earlier in this cell)
if 'timestamp_pattern' not in locals():
     print("Error: timestamp_pattern not defined.")
     timestamp_pattern = re.compile(r"dummy_ts_pattern") # Avoid crash

# 5. Chunk the processed SRT data by chapter
chapter_chunks: List[ChunkedSRTItem] = []
if processed_srt_str and 'chapter_pattern_text' in locals() and 'chapter_pattern_int' in locals() and 'timestamp_pattern' in locals():
    try:
        # Ensure the chunking function is available (defined in cell c8ce6d60)
        if 'chunking_srt_by_chapter' in globals():
             chapter_chunks = chunking_srt_by_chapter(
                 processed_srt_str,
                 chapter_pattern_text,
                 chapter_pattern_int,
                 timestamp_pattern
             )
        else:
            print("Error: chunking_srt_by_chapter function not found.")
    except Exception as e:
        print(f"Error during chunking: {e}")
else:
    print("Skipping chunking due to missing processed SRT data or chapter patterns.")
total_length = 0
for i in original_parsed_srt_data:
    total_length += (len(i.text.split(' ')))
# print(total_length)
# --- Run the main function ---
if llm and chapter_chunks and original_parsed_srt_data:
    print("\n--- Calling identify_interesting_points_structured ---")
    summary, evidence = identify_interesting_points_structured(
        chunked_data=chapter_chunks,
        llm=llm,
        output_schema=SummaryAndEvidence,
        original_data=original_parsed_srt_data, # Pass the original parsed data
        cache_file_path= cache_filepath, # Path to cache file
        min_snippet_word_count=5,
        is_one_p=total_length <= 8192 
    )
    print("\n--- Summary ---")
    print(summary if summary else "No summary generated.")
    print("\n--- Processed Evidence ---")
    if evidence:
        for i, ev in enumerate(evidence):
            idx = ev.get('matched_index', 'N/A')
            ts = ev.get('timestamp', ('N/A', 'N/A'))
            score = ev.get('match_score', 0)
            text = ev.get('text', '')
            print(f"{i+1}. Index: {idx}, TS: {ts}, Score: {score:.2f}, Text: {text[:100]}...")
    else:
        print("No evidence snippets processed.")
else:
    print("\n--- Execution Skipped ---")
    if not llm: print("Reason: LLM not initialized.")
    if not chapter_chunks: print("Reason: Chapter chunks are empty or not generated.")
    if not original_parsed_srt_data: print("Reason: Original parsed SRT data is missing.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 58
#      53     else:
#      54         return raw_snippet_text.strip(), None
#      56 def _find_matching_block(
#      57     segment_text: str,
# ---> 58     original_material: List[SRTItem], # List of parsed ORIGINAL SRT dicts
#      59     min_similarity_threshold: float = 0.4 # Threshold for considering a match
#      60 ) -> Tuple[Optional[Dict[str, Any]], float]:
#      61     """
#      62     Finds the best matching text block in the *original* parsed SRT data for a given segment text
#      63     using similarity matching. Matches against the 'text' field in original_material.
#      64     """
#      65     norm_segment = ' '.join(segment_text.split())
#
# NameError: name 'SRTItem' is not defined

# %%
# Merging Intervals within 1s proximity range
intervals = [(1,5),(6,9),(11,15),(16,20),(21,25)]
pointer = 0
curr_interval = intervals[pointer]
merged_intervals = []
for i in range(1, len(intervals)):
    if intervals[i][0] - curr_interval[1] <= 1:  # Check if the start of the current interval is within 1s of the end of the last merged interval
        curr_interval = (curr_interval[0], intervals[i][1])
        continue
    merged_intervals.append(curr_interval)
    curr_interval = intervals[i]
merged_intervals.append(curr_interval)  # Add the last interval after the loop
print(merged_intervals)  # Output the merged intervals
# Out:
# [(1, 9), (11, 25)]

# %%
# In cell with id 'e149cdf7'

import json
import re
from pydub import AudioSegment
# ...existing code...
import traceback # Import traceback for detailed error logging
import os # Ensure os is imported

class SnippetItem:
    """Represents a single snippet with its text and timestamp."""
    def __init__(self, text: str, timestamp: Tuple[int, int]):
        self.text = text
        self.timestamp = timestamp

    def __repr__(self):
        return f"SnippetItem(text={self.text[:30]}..., timestamp={self.timestamp})"

# --- Configuration ---
# Use the correct master cache file name based on the previous cell's output
srt_basename = os.path.basename(original_srt_filepath) # Assumes original_srt_filepath is defined in the previous cell
srt_name_no_ext = os.path.splitext(srt_basename)[0]
master_cache_filename = f"{srt_name_no_ext}_summary_evidence_cache_master.json"
master_cache_file_path = os.path.join(cache_dir, master_cache_filename) # Assumes cache_dir is defined
chunks_dir = os.path.join(cache_dir, f"{srt_name_no_ext}_summary_evidence_cache_chunks") # Directory containing individual chunk JSONs

audio_file_path = r"D:\DATA300\AudioBookSum\data\AtomicHabit\AtomicHabitsAnEasyProvenWaytoBuildGoodHabitsBreakBadOnes.flac" # Ensure this path is correct
base_output_dir = r"d:\DATA300\AudioBookSum\output_snippets_by_chunk" # Base directory to save chunk snippet folders

# Regex pattern for timestamp (ensure it's defined or copied from the previous cell)
timestamp_re_str = r'\s*\[\s*(\d{2}:\d{2}:\d{2},\d{3})\s*,\s*(\d{2}:\d{2}:\d{2},\d{3})\s*\]\s*'
timestamp_pattern = re.compile(timestamp_re_str)

def srt_timestamp_to_ms(timestamp_str):
    """Converts an SRT timestamp string (HH:MM:SS,ms) to milliseconds."""
    try:
        h, m, s_ms = timestamp_str.split(':')
        s, ms = s_ms.split(',')
        # Add a small buffer (e.g., 100ms) to the end time to avoid cutting off audio slightly early
        # Keep start time precise
        total_ms = int(h) * 3600000 + int(m) * 60000 + int(s) * 1000 + int(ms)
        return total_ms
    except ValueError as e:
        print(f"Error converting timestamp '{timestamp_str}': {e}")
        raise # Re-raise the error to be caught later

def save_merged_snippet(interval_ms, text, audio_segment, output_dir, snippet_index):
    """Saves the merged audio snippet and its corresponding transcript."""
    global total_snippets_saved # Use global counter

    start_ms, end_ms = interval_ms
    # Add buffer to end time for audio cutting only
    buffered_end_ms = end_ms + 100
    print(f"  Saving merged snippet: {text[:50]}... from {start_ms}ms to {end_ms}ms")

    try:
        # --- Cut Audio ---
        snippet = audio_segment[start_ms:buffered_end_ms]

        # --- Create Filenames ---
        # Clean text for filename preview (use start time for uniqueness)
        clean_text_preview = re.sub(r'[\\/*?:\"<>|,.]', '', text)[:30]
        safe_filename_part = re.sub(r'\s+', '_', clean_text_preview)
        base_filename = f"merged_snippet_{snippet_index:03d}_{start_ms}_{safe_filename_part}"
        audio_output_filename = os.path.join(output_dir, f"{base_filename}.mp3")
        text_output_filename = os.path.join(output_dir, f"{base_filename}.txt")

        # --- Save Audio ---
        snippet.export(audio_output_filename, format="mp3")
        print(f"    Audio saved to: {audio_output_filename}")

        # --- Save Transcript ---
        with open(text_output_filename, 'w', encoding='utf-8') as f:
            f.write(text)
        print(f"    Transcript saved to: {text_output_filename}")

        total_snippets_saved += 1
        return True # Indicate success

    except Exception as e:
        print(f"    Error saving merged snippet starting at {start_ms}ms: {e}")
        print(traceback.format_exc())
        return False # Indicate failure

# Create base output directory if it doesn't exist
os.makedirs(base_output_dir, exist_ok=True)

# --- Load Master Cache ---
chunk_files = []
try:
    print(f"Loading master cache index from: {master_cache_file_path}")
    with open(master_cache_file_path, 'r', encoding='utf-8') as f:
        master_data = json.load(f)
    chunk_files = master_data.get("chunk_files", [])
    if not chunk_files:
        print(f"Warning: No 'chunk_files' listed in {master_cache_file_path}")
    else:
        print(f"Found {len(chunk_files)} chunk files listed in master cache.")
except FileNotFoundError:
    print(f"Error: Master cache file not found at {master_cache_file_path}")
except json.JSONDecodeError:
    print(f"Error: Could not decode JSON from {master_cache_file_path}")
except Exception as e:
    print(f"An unexpected error occurred while reading master cache: {e}")
    print(traceback.format_exc())

# --- Load Audio File ---
audio = None
if chunk_files:
    try:
        print(f"Loading audio file: {audio_file_path}...")
        audio = AudioSegment.from_file(audio_file_path, format="flac")
        print("Audio file loaded successfully.")
    except FileNotFoundError:
        print(f"Error: Audio file not found at {audio_file_path}")
    except Exception as e:
        print(f"Error loading audio file with pydub: {e}")
        print("Ensure ffmpeg is installed and in your system's PATH.")
        print(traceback.format_exc())

total_snippets_processed = 0
total_snippets_saved = 0 

if audio and chunk_files:
    print(f"\n--- Processing {len(chunk_files)} Chunk Files ---")
    for chunk_filename in chunk_files:
        chunk_file_path = os.path.join(chunks_dir, chunk_filename)
        chunk_output_dir_name = os.path.splitext(chunk_filename)[0] # e.g., "chunk_000"
        chunk_output_dir = os.path.join(base_output_dir, chunk_output_dir_name)
        os.makedirs(chunk_output_dir, exist_ok=True)

        print(f"\nProcessing chunk file: {chunk_filename} -> Outputting to: {chunk_output_dir}")

        evidence_list_raw = []
        try:
            with open(chunk_file_path, 'r', encoding='utf-8') as f:
                chunk_data = json.load(f)
            evidence_list_raw = chunk_data.get("evidence", [])
            if not evidence_list_raw:
                print(f"  No 'evidence' found in {chunk_filename}. Skipping.")
                continue
            print(f"  Found {len(evidence_list_raw)} raw evidence items in this chunk.")

        except FileNotFoundError:
            print(f"  Error: Chunk file not found at {chunk_file_path}. Skipping.")
            continue
        except json.JSONDecodeError:
            print(f"  Error: Could not decode JSON from {chunk_file_path}. Skipping.")
            continue
        except Exception as e:
            print(f"  An unexpected error occurred while reading {chunk_filename}: {e}")
            print(traceback.format_exc())
            continue

        # --- Process Evidence, Merge Consecutive, and Cut Snippets ---
        chunk_snippets_saved_count = 0
        current_merged_interval = None
        current_merged_text = ""
        merge_proximity_ms = 1000 

        for i, item in enumerate(evidence_list_raw):
            total_snippets_processed += 1
            verbatim_text = item.get("verbatim_text", "")
            if not verbatim_text.strip():
                print(f"  Skipping empty evidence item {i+1} in {chunk_filename}.")
                continue

            match = timestamp_pattern.match(verbatim_text)
            if not match:
                print(f"  Skipping evidence item {i+1}: Could not extract timestamp from text: {verbatim_text[:50]}...")
                continue

            start_ts_str, end_ts_str = match.groups()
            text_content = verbatim_text[match.end():].strip()

            try:
                start_ms = srt_timestamp_to_ms(start_ts_str)
                end_ms = srt_timestamp_to_ms(end_ts_str)

                # Basic sanity check
                if start_ms >= end_ms:
                    print(f"  Skipping snippet {i+1}: Start time ({start_ms}ms) is not before end time ({end_ms}ms). Text: {text_content[:50]}...")
                    continue

                # --- Merging Logic ---
                if current_merged_interval is None:
                    # Start a new merged interval
                    current_merged_interval = (start_ms, end_ms)
                    current_merged_text = text_content
                elif start_ms - current_merged_interval[1] <= merge_proximity_ms:
                    # Merge with the previous interval: extend end time and append text
                    current_merged_interval = (current_merged_interval[0], max(current_merged_interval[1], end_ms)) # Take the later end time
                    current_merged_text += " " + text_content
                else:
                    # Gap detected: Save the PREVIOUS merged interval
                    if save_merged_snippet(current_merged_interval, current_merged_text, audio, chunk_output_dir, chunk_snippets_saved_count + 1):
                         chunk_snippets_saved_count += 1
                    # Start a NEW merged interval with the current item
                    current_merged_interval = (start_ms, end_ms)
                    current_merged_text = text_content

            except ValueError as e: # Catch timestamp conversion errors
                print(f"  Skipping snippet {i+1}: Error converting timestamp - {e}. Text: {verbatim_text[:50]}...")
                # If error occurs, reset current merge state to avoid issues
                current_merged_interval = None
                current_merged_text = ""
                continue
            except Exception as e: # Catch other unexpected errors during processing
                print(f"  Skipping snippet {i+1}: Unexpected error processing item - {e}. Text: {verbatim_text[:50]}...")
                print(traceback.format_exc())
                current_merged_interval = None
                current_merged_text = ""
                continue

        # --- Save the LAST merged interval after the loop ---
        if current_merged_interval is not None:
            if save_merged_snippet(current_merged_interval, current_merged_text, audio, chunk_output_dir, chunk_snippets_saved_count + 1):
                 chunk_snippets_saved_count += 1

        print(f"  Finished processing chunk {chunk_filename}. Saved {chunk_snippets_saved_count} merged snippets.")


    print(f"\n--- Overall Summary ---")
    print(f"Processed {total_snippets_processed} raw evidence items across all chunks.")
    print(f"Successfully extracted and saved {total_snippets_saved} merged audio snippets and transcripts to respective folders in {base_output_dir}")

else:
    print("\n--- Execution Skipped ---")
    if not audio:
        print("Reason: Audio file could not be loaded.")
    if not chunk_files:
         print("Reason: No chunk files found or loaded from the master cache.")
# Out:
# Loading master cache index from: d:\DATA300\AudioBookSum\src\cache\transcribed (2)_summary_evidence_cache_master.json
# Found 28 chunk files listed in master cache.
# Loading audio file: D:\DATA300\AudioBookSum\data\AtomicHabit\AtomicHabitsAnEasyProvenWaytoBuildGoodHabitsBreakBadOnes.flac...
# Audio file loaded successfully.
#
# --- Processing 28 Chunk Files ---
#
# Processing chunk file: chunk_000.json -> Outputting to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_000
#   Found 14 raw evidence items in this chunk.
#   Saving merged snippet: An easy and proven way to build good habits and br... from 6481ms to 12685ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_000\merged_snippet_001_6481_An_easy_and_proven_way_to_buil.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_000\merged_snippet_001_6481_An_easy_and_proven_way_to_buil.txt
#   Saving merged snippet: Atomic. One. An extremely small amount of a thing.... from 20250ms to 27775ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_000\merged_snippet_002_20250_Atomic_One_An_extremely_small_.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_000\merged_snippet_002_20250_Atomic_One_An_extremely_small_.txt
#   Saving merged snippet: Habit, one, a routine or practice performed regula... from 33843ms to 41948ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_000\merged_snippet_003_33843_Habit_one_a_routine_or_practic.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_000\merged_snippet_003_33843_Habit_one_a_routine_or_practic.txt
#   Saving merged snippet: On the final day of my sophomore year of high scho... from 51453ms to 55676ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_000\merged_snippet_004_51453_On_the_final_day_of_my_sophomo.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_000\merged_snippet_004_51453_On_the_final_day_of_my_sophomo.txt
#   Saving merged snippet: Mercifully, by the next morning, my breathing had ... from 330782ms to 336526ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_000\merged_snippet_005_330782_Mercifully_by_the_next_morning.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_000\merged_snippet_005_330782_Mercifully_by_the_next_morning.txt
#   Saving merged snippet: The turning point came two years after my injury, ... from 483491ms to 487872ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_000\merged_snippet_006_483491_The_turning_point_came_two_yea.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_000\merged_snippet_006_483491_The_turning_point_came_two_yea.txt
#   Saving merged snippet: While my peers stayed up late and played video gam... from 519830ms to 524631ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_000\merged_snippet_007_519830_While_my_peers_stayed_up_late_.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_000\merged_snippet_007_519830_While_my_peers_stayed_up_late_.txt
#   Saving merged snippet: A habit is a routine or behavior that is performed... from 544708ms to 549910ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_000\merged_snippet_008_544708_A_habit_is_a_routine_or_behavi.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_000\merged_snippet_008_544708_A_habit_is_a_routine_or_behavi.txt
#   Saving merged snippet: Six years after I had been hit in the face with a ... from 588815ms to 603398ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_000\merged_snippet_009_588815_Six_years_after_I_had_been_hit.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_000\merged_snippet_009_588815_Six_years_after_I_had_been_hit.txt
#   Saving merged snippet: How and why I wrote this book.  In November 2012, ... from 693552ms to 700526ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_000\merged_snippet_010_693552_How_and_why_I_wrote_this_book_.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_000\merged_snippet_010_693552_How_and_why_I_wrote_this_book_.txt
#   Saving merged snippet: The entrepreneur and investor Naval Ravikant has s... from 838104ms to 843969ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_000\merged_snippet_011_838104_The_entrepreneur_and_investor_.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_000\merged_snippet_011_838104_The_entrepreneur_and_investor_.txt
#   Saving merged snippet: In what follows, I will share a step-by-step plan ... from 870588ms to 876712ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_000\merged_snippet_012_870588_In_what_follows_I_will_share_a.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_000\merged_snippet_012_870588_In_what_follows_I_will_share_a.txt
#   Saving merged snippet: The backbone of this book is my four-step model of... from 924916ms to 934666ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_000\merged_snippet_013_924916_The_backbone_of_this_book_is_m.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_000\merged_snippet_013_924916_The_backbone_of_this_book_is_m.txt
#   Saving merged snippet: There is no one right way to create better habits,... from 1029207ms to 1039712ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_000\merged_snippet_014_1029207_There_is_no_one_right_way_to_c.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_000\merged_snippet_014_1029207_There_is_no_one_right_way_to_c.txt
#   Finished processing chunk chunk_000.json. Saved 14 merged snippets.
#
# Processing chunk file: chunk_001.json -> Outputting to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001
#   Found 38 raw evidence items in this chunk.
#   Saving merged snippet: The Fundamentals – Why Tiny Changes Make a Big Dif... from 1060361ms to 1074349ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_001_1060361_The_Fundamentals_–_Why_Tiny_Ch.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_001_1060361_The_Fundamentals_–_Why_Tiny_Ch.txt
#   Saving merged snippet: At the time, professional cyclists in Great Britai... from 1084974ms to 1095358ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_002_1084974_At_the_time_professional_cycli.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_002_1084974_At_the_time_professional_cycli.txt
#   Saving merged snippet: In 110 years, no British cyclist had ever won the ... from 1100440ms to 1103922ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_003_1100440_In_110_years_no_British_cyclis.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_003_1100440_In_110_years_no_British_cyclis.txt
#   Saving merged snippet: Brailsford had been hired to put British cycling o... from 1119238ms to 1130582ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_004_1119238_Brailsford_had_been_hired_to_p.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_004_1119238_Brailsford_had_been_hired_to_p.txt
#   Saving merged snippet: which was the philosophy of searching for a tiny m... from 1131638ms to 1135701ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_005_1131638_which_was_the_philosophy_of_se.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_005_1131638_which_was_the_philosophy_of_se.txt
#   Saving merged snippet: Brailsford said, the whole principle came from the... from 1136722ms to 1148292ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_006_1136722_Brailsford_said_the_whole_prin.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_006_1136722_Brailsford_said_the_whole_prin.txt
#   Saving merged snippet: As these and hundreds of other small improvements ... from 1216263ms to 1221848ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_007_1216263_As_these_and_hundreds_of_other.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_007_1216263_As_these_and_hundreds_of_other.txt
#   Saving merged snippet: Just five years after Brailsford took over, the Br... from 1223019ms to 1234712ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_008_1223019_Just_five_years_after_Brailsfo.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_008_1223019_Just_five_years_after_Brailsfo.txt
#   Saving merged snippet: That same year, Bradley Wiggins became the first B... from 1244214ms to 1248257ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_009_1244214_That_same_year_Bradley_Wiggins.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_009_1244214_That_same_year_Bradley_Wiggins.txt
#   Saving merged snippet: During the 10-year span from 2007 to 2017, British... from 1261546ms to 1278541ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_010_1261546_During_the_10-year_span_from_2.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_010_1261546_During_the_10-year_span_from_2.txt
#   Saving merged snippet: Habits are the compound interest of self-improveme... from 1384432ms to 1386913ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_011_1384432_Habits_are_the_compound_intere.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_011_1384432_Habits_are_the_compound_intere.txt
#   Saving merged snippet: They seem to make little difference on any given d... from 1393816ms to 1399899ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_012_1393816_They_seem_to_make_little_diffe.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_012_1393816_They_seem_to_make_little_diffe.txt
#   Saving merged snippet: We often dismiss small changes because they don't ... from 1413585ms to 1417328ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_013_1413585_We_often_dismiss_small_changes.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_013_1413585_We_often_dismiss_small_changes.txt
#   Saving merged snippet: Success is the product of daily habits, not once-i... from 1546247ms to 1550352ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_014_1546247_Success_is_the_product_of_dail.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_014_1546247_Success_is_the_product_of_dail.txt
#   Saving merged snippet: Your outcomes are a lagging measure of your habits... from 1581390ms to 1586812ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_015_1581390_Your_outcomes_are_a_lagging_me.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_015_1581390_Your_outcomes_are_a_lagging_me.txt
#   Saving merged snippet: Your clutter is a lagging measure of your cleaning... from 1592634ms to 1596495ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_016_1592634_Your_clutter_is_a_lagging_meas.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_016_1592634_Your_clutter_is_a_lagging_meas.txt
#   Saving merged snippet: Habits are a double-edged sword. Bad habits can cu... from 1748152ms to 1755976ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_017_1748152_Habits_are_a_double-edged_swor.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_017_1748152_Habits_are_a_double-edged_swor.txt
#   Saving merged snippet: Breakthrough moments are often the result of many ... from 1803567ms to 1809650ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_018_1803567_Breakthrough_moments_are_often.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_018_1803567_Breakthrough_moments_are_often.txt
#   Saving merged snippet: Similarly, habits often appear to make no differen... from 1825999ms to 1832683ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_019_1825999_Similarly_habits_often_appear_.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_019_1825999_Similarly_habits_often_appear_.txt
#   Saving merged snippet: In the early and middle stages of any quest, there... from 1837708ms to 1845637ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_020_1837708_In_the_early_and_middle_stages.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_020_1837708_In_the_early_and_middle_stages.txt
#   Saving merged snippet: But in order to make a meaningful difference, habi... from 1874388ms to 1882251ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_021_1874388_But_in_order_to_make_a_meaning.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_021_1874388_But_in_order_to_make_a_meaning.txt
#   Saving merged snippet: Yet, at the 101st blow, it will split in two, and ... from 1973025ms to 1980030ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_022_1973025_Yet_at_the_101st_blow_it_will_.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_022_1973025_Yet_at_the_101st_blow_it_will_.txt
#   Saving merged snippet: All big things come from small beginnings. The see... from 1981492ms to 1986656ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_023_1981492_All_big_things_come_from_small.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_023_1981492_All_big_things_come_from_small.txt
#   Saving merged snippet: Forget about goals. Focus on systems instead.... from 2022337ms to 2024958ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_024_2022337_Forget_about_goals_Focus_on_sy.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_024_2022337_Forget_about_goals_Focus_on_sy.txt
#   Saving merged snippet: Goals are about the results you want to achieve. S... from 2073403ms to 2079089ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_025_2073403_Goals_are_about_the_results_yo.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_025_2073403_Goals_are_about_the_results_yo.txt
#   Saving merged snippet: The same is true for other areas of life. If you w... from 2144400ms to 2151544ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_026_2144400_The_same_is_true_for_other_are.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_026_2144400_The_same_is_true_for_other_are.txt
#   Saving merged snippet: And if successful and unsuccessful people share th... from 2195675ms to 2202556ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_027_2195675_And_if_successful_and_unsucces.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_027_2195675_And_if_successful_and_unsucces.txt
#   Saving merged snippet: You're left chasing the same outcome because you n... from 2244630ms to 2248252ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_028_2244630_You're_left_chasing_the_same_o.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_028_2244630_You're_left_chasing_the_same_o.txt
#   Saving merged snippet: What we really need to change are the systems that... from 2261588ms to 2265369ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_029_2261588_What_we_really_need_to_change_.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_029_2261588_What_we_really_need_to_change_.txt
#   Saving merged snippet: The purpose of setting goals is to win the game. T... from 2381265ms to 2386788ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_030_2381265_The_purpose_of_setting_goals_i.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_030_2381265_The_purpose_of_setting_goals_i.txt
#   Saving merged snippet: Bad habits repeat themselves again and again, not ... from 2411650ms to 2424200ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_031_2411650_Bad_habits_repeat_themselves_a.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_031_2411650_Bad_habits_repeat_themselves_a.txt
#   Saving merged snippet: By now, you have probably realized that an atomic ... from 2435012ms to 2441594ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_032_2435012_By_now_you_have_probably_reali.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_032_2435012_By_now_you_have_probably_reali.txt
#   Saving merged snippet: Just as atoms are the building blocks of molecules... from 2449537ms to 2455299ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_033_2449537_Just_as_atoms_are_the_building.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_001\merged_snippet_033_2449537_Just_as_atoms_are_the_building.txt
#   Finished processing chunk chunk_001.json. Saved 33 merged snippets.
#
# Processing chunk file: chunk_002.json -> Outputting to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002
#   Found 24 raw evidence items in this chunk.
#   Saving merged snippet: Chapter 2 How Your Habits Shape Your Identity, and... from 2550528ms to 2561020ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_001_2550528_Chapter_2_How_Your_Habits_Shap.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_001_2550528_Chapter_2_How_Your_Habits_Shap.txt
#   Saving merged snippet: Few things can have a more powerful impact on your... from 2562081ms to 2566086ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_002_2562081_Few_things_can_have_a_more_pow.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_002_2562081_Few_things_can_have_a_more_pow.txt
#   Saving merged snippet: Changing our habits is challenging for two reasons... from 2603478ms to 2611521ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_003_2603478_Changing_our_habits_is_challen.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_003_2603478_Changing_our_habits_is_challen.txt
#   Saving merged snippet: The first layer is changing your outcomes.... from 2636865ms to 2638968ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_004_2636865_The_first_layer_is_changing_yo.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_004_2636865_The_first_layer_is_changing_yo.txt
#   Saving merged snippet: This level is concerned with changing your habits ... from 2651504ms to 2654065ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_005_2651504_This_level_is_concerned_with_c.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_005_2651504_This_level_is_concerned_with_c.txt
#   Saving merged snippet: Most of the habits you build are associated with t... from 2661527ms to 2667749ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_006_2661527_Most_of_the_habits_you_build_a.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_006_2661527_Most_of_the_habits_you_build_a.txt
#   Saving merged snippet: Outcomes are about what you get. Processes are abo... from 2681763ms to 2687386ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_007_2681763_Outcomes_are_about_what_you_ge.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_007_2681763_Outcomes_are_about_what_you_ge.txt
#   Saving merged snippet: Many people begin the process of changing their ha... from 2702919ms to 2707641ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_008_2702919_Many_people_begin_the_process_.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_008_2702919_Many_people_begin_the_process_.txt
#   Saving merged snippet: With this approach, we start by focusing on who we... from 2714164ms to 2717585ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_009_2714164_With_this_approach_we_start_by.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_009_2714164_With_this_approach_we_start_by.txt
#   Saving merged snippet: Behind every system of actions are a system of bel... from 2784288ms to 2786990ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_010_2784288_Behind_every_system_of_actions.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_010_2784288_Behind_every_system_of_actions.txt
#   Saving merged snippet: Behavior that is incongruent with the self will no... from 2827061ms to 2829923ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_011_2827061_Behavior_that_is_incongruent_w.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_011_2827061_Behavior_that_is_incongruent_w.txt
#   Saving merged snippet: It's hard to change your habits if you never chang... from 2847270ms to 2851811ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_012_2847270_It's_hard_to_change_your_habit.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_012_2847270_It's_hard_to_change_your_habit.txt
#   Saving merged snippet: True behavior change is identity change.... from 2954989ms to 2957090ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_013_2954989_True_behavior_change_is_identi.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_013_2954989_True_behavior_change_is_identi.txt
#   Saving merged snippet: The goal is not to read a book. The goal is to bec... from 2978857ms to 2990762ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_014_2978857_The_goal_is_not_to_read_a_book.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_014_2978857_The_goal_is_not_to_read_a_book.txt
#   Saving merged snippet: Once you have adopted an identity, it can be easy ... from 3051135ms to 3056480ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_015_3051135_Once_you_have_adopted_an_ident.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_015_3051135_Once_you_have_adopted_an_ident.txt
#   Saving merged snippet: The biggest barrier to positive change at any leve... from 3117103ms to 3123008ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_016_3117103_The_biggest_barrier_to_positiv.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_016_3117103_The_biggest_barrier_to_positiv.txt
#   Saving merged snippet: This is why you can't get too attached to one vers... from 3144074ms to 3149296ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_017_3144074_This_is_why_you_can't_get_too_.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_017_3144074_This_is_why_you_can't_get_too_.txt
#   Saving merged snippet: The two-step process to changing your identity You... from 3175750ms to 3181535ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_018_3175750_The_two-step_process_to_changi.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_018_3175750_The_two-step_process_to_changi.txt
#   Saving merged snippet: To put it more precisely, your habits are how you ... from 3211140ms to 3215582ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_019_3211140_To_put_it_more_precisely_your_.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_019_3211140_To_put_it_more_precisely_your_.txt
#   Saving merged snippet: Your identity is literally your repeated beingness... from 3239199ms to 3242285ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_020_3239199_Your_identity_is_literally_you.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_020_3239199_Your_identity_is_literally_you.txt
#   Saving merged snippet: Putting this all together, you can see that habits... from 3388936ms to 3392899ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_021_3388936_Putting_this_all_together_you_.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_021_3388936_Putting_this_all_together_you_.txt
#   Saving merged snippet: One, decide the type of person you want to be. Two... from 3466688ms to 3472970ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_022_3466688_One_decide_the_type_of_person_.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_022_3466688_One_decide_the_type_of_person_.txt
#   Saving merged snippet: The Real Reason Habits Matter Identity change is t... from 3604129ms to 3609550ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_023_3604129_The_Real_Reason_Habits_Matter_.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_002\merged_snippet_023_3604129_The_Real_Reason_Habits_Matter_.txt
#   Finished processing chunk chunk_002.json. Saved 23 merged snippets.
#
# Processing chunk file: chunk_003.json -> Outputting to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003
#   Found 37 raw evidence items in this chunk.
#   Saving merged snippet: In 1898, a psychologist named Edward Thorndike con... from 3744732ms to 3754379ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_001_3744732_In_1898_a_psychologist_named_E.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_001_3744732_In_1898_a_psychologist_named_E.txt
#   Saving merged snippet: Thorndike was interested in studying the behavior ... from 3755620ms to 3764086ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_002_3755620_Thorndike_was_interested_in_st.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_002_3755620_Thorndike_was_interested_in_st.txt
#   Saving merged snippet: In the beginning, the animals moved around the box... from 3804459ms to 3806980ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_003_3804459_In_the_beginning_the_animals_m.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_003_3804459_In_the_beginning_the_animals_m.txt
#   Saving merged snippet: Gradually, each cat learned to associate the actio... from 3812538ms to 3819147ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_004_3812538_Gradually_each_cat_learned_to_.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_004_3812538_Gradually_each_cat_learned_to_.txt
#   Saving merged snippet: After 20 to 30 trials, this behavior became so aut... from 3820429ms to 3826257ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_005_3820429_After_20_to_30_trials_this_beh.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_005_3820429_After_20_to_30_trials_this_beh.txt
#   Saving merged snippet: From his studies, Thorndike described the learning... from 3876444ms to 3887587ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_006_3876444_From_his_studies_Thorndike_des.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_006_3876444_From_his_studies_Thorndike_des.txt
#   Saving merged snippet: A habit is a behavior that has been repeated enoug... from 3904274ms to 3917821ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_007_3904274_A_habit_is_a_behavior_that_has.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_007_3904274_A_habit_is_a_behavior_that_has.txt
#   Saving merged snippet: The brain is busy learning the most effective cour... from 3939216ms to 3941797ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_008_3939216_The_brain_is_busy_learning_the.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_008_3939216_The_brain_is_busy_learning_the.txt
#   Saving merged snippet: With practice, the useless movements fade away and... from 3979599ms to 3985220ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_009_3979599_With_practice_the_useless_move.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_009_3979599_With_practice_the_useless_move.txt
#   Saving merged snippet: Your habits are just a series of automatic solutio... from 3991806ms to 3996910ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_010_3991806_Your_habits_are_just_a_series_.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_010_3991806_Your_habits_are_just_a_series_.txt
#   Saving merged snippet: As habits are created, the level of activity in th... from 4006217ms to 4009639ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_011_4006217_As_habits_are_created_the_leve.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_011_4006217_As_habits_are_created_the_leve.txt
#   Saving merged snippet: Habits are mental shortcuts learned from experienc... from 4047523ms to 4049564ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_012_4047523_Habits_are_mental_shortcuts_le.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_012_4047523_Habits_are_mental_shortcuts_le.txt
#   Saving merged snippet: Habit formation is incredibly useful because the c... from 4067517ms to 4071739ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_013_4067517_Habit_formation_is_incredibly_.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_013_4067517_Habit_formation_is_incredibly_.txt
#   Saving merged snippet: Habits reduce cognitive load and free up mental ca... from 4091010ms to 4096993ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_014_4091010_Habits_reduce_cognitive_load_a.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_014_4091010_Habits_reduce_cognitive_load_a.txt
#   Saving merged snippet: In reality, the two complement each other. Habits ... from 4121505ms to 4126808ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_015_4121505_In_reality_the_two_complement_.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_015_4121505_In_reality_the_two_complement_.txt
#   Saving merged snippet: The science of how habits work. The process of bui... from 4175486ms to 4181431ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_016_4175486_The_science_of_how_habits_work.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_016_4175486_The_science_of_how_habits_work.txt
#   Saving merged snippet: Cue, craving, response, and reward. Readers of The... from 4182432ms to 4190358ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_017_4182432_Cue_craving_response_and_rewar.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_017_4182432_Cue_craving_response_and_rewar.txt
#   Saving merged snippet: This four-step pattern is the backbone of every ha... from 4209235ms to 4215078ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_018_4209235_This_four-step_pattern_is_the_.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_018_4209235_This_four-step_pattern_is_the_.txt
#   Saving merged snippet: First, there's the cue. The cue triggers your brai... from 4216219ms to 4220361ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_019_4216219_First_there's_the_cue_The_cue_.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_019_4216219_First_there's_the_cue_The_cue_.txt
#   Saving merged snippet: Cravings are the second step, and they are the mot... from 4267350ms to 4271033ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_020_4267350_Cravings_are_the_second_step_a.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_020_4267350_Cravings_are_the_second_step_a.txt
#   Saving merged snippet: The response is the actual habit you perform, whic... from 4335759ms to 4340282ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_021_4335759_The_response_is_the_actual_hab.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_021_4335759_The_response_is_the_actual_hab.txt
#   Saving merged snippet: Finally, the response delivers a reward.  Rewards ... from 4365404ms to 4370497ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_022_4365404_Finally_the_response_delivers_.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_022_4365404_Finally_the_response_delivers_.txt
#   Saving merged snippet: Second, rewards teach us which actions are worth r... from 4414462ms to 4420748ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_023_4414462_Second_rewards_teach_us_which_.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_023_4414462_Second_rewards_teach_us_which_.txt
#   Saving merged snippet: If a behavior is insufficient in any of these four... from 4440832ms to 4444913ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_024_4440832_If_a_behavior_is_insufficient_.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_024_4440832_If_a_behavior_is_insufficient_.txt
#   Saving merged snippet: In summary, the cue triggers a craving, which moti... from 4476694ms to 4486758ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_025_4476694_In_summary_the_cue_triggers_a_.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_025_4476694_In_summary_the_cue_triggers_a_.txt
#   Saving merged snippet: The problem phase includes the cue and the craving... from 4534172ms to 4546459ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_026_4534172_The_problem_phase_includes_the.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_026_4534172_The_problem_phase_includes_the.txt
#   Saving merged snippet: All behavior is driven by the desire to solve a pr... from 4547988ms to 4550490ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_027_4547988_All_behavior_is_driven_by_the_.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_027_4547988_All_behavior_is_driven_by_the_.txt
#   Saving merged snippet: In the following chapters, we will see time and ag... from 4672119ms to 4679781ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_028_4672119_In_the_following_chapters_we_w.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_028_4672119_In_the_following_chapters_we_w.txt
#   Saving merged snippet: I refer to this framework as the Four Laws of Beha... from 4689508ms to 4696973ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_029_4689508_I_refer_to_this_framework_as_t.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_029_4689508_I_refer_to_this_framework_as_t.txt
#   Saving merged snippet: Here's how you can use the four laws to create a g... from 4715154ms to 4729745ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_030_4715154_Here's_how_you_can_use_the_fou.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_030_4715154_Here's_how_you_can_use_the_fou.txt
#   Saving merged snippet: The ultimate purpose of habits is to solve the pro... from 4834227ms to 4840389ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_031_4834227_The_ultimate_purpose_of_habits.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_031_4834227_The_ultimate_purpose_of_habits.txt
#   Saving merged snippet: Any habit can be broken down into a feedback loop ... from 4841530ms to 4847853ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_032_4841530_Any_habit_can_be_broken_down_i.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_003\merged_snippet_032_4841530_Any_habit_can_be_broken_down_i.txt
#   Finished processing chunk chunk_003.json. Saved 32 merged snippets.
#
# Processing chunk file: chunk_004.json -> Outputting to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_004
#   Found 134 raw evidence items in this chunk.
#   Saving merged snippet: The psychologist Gary Klein once told me a story a... from 4877668ms to 4891657ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_004\merged_snippet_001_4877668_The_psychologist_Gary_Klein_on.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_004\merged_snippet_001_4877668_The_psychologist_Gary_Klein_on.txt
#   Saving merged snippet: A few hours later, the man was undergoing life-sav... from 4901775ms to 4913719ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_004\merged_snippet_002_4901775_A_few_hours_later_the_man_was_.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_004\merged_snippet_002_4901775_A_few_hours_later_the_man_was_.txt
#   Saving merged snippet: When major arteries are obstructed, the body focus... from 4919861ms to 4943255ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_004\merged_snippet_003_4919861_When_major_arteries_are_obstru.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_004\merged_snippet_003_4919861_When_major_arteries_are_obstru.txt
#   Saving merged snippet: For example, military analysts can identify which ... from 4947260ms to 4960837ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_004\merged_snippet_004_4947260_For_example_military_analysts_.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_004\merged_snippet_004_4947260_For_example_military_analysts_.txt
#   Saving merged snippet: During the Gulf War, Lieutenant Commander Michael ... from 4961841ms to 4971490ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_004\merged_snippet_005_4961841_During_the_Gulf_War_Lieutenant.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_004\merged_snippet_005_4961841_During_the_Gulf_War_Lieutenant.txt
#   Saving merged snippet: Museum curators have been known to discern the dif... from 4976835ms to 4993589ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_004\merged_snippet_006_4976835_Museum_curators_have_been_know.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_004\merged_snippet_006_4976835_Museum_curators_have_been_know.txt
#   Saving merged snippet: I've even heard of hairdressers noticing whether a... from 4994590ms to 4998993ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_004\merged_snippet_007_4994590_I've_even_heard_of_hairdresser.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_004\merged_snippet_007_4994590_I've_even_heard_of_hairdresser.txt
#   Saving merged snippet: The human brain is a prediction machine. It is con... from 5000375ms to 5023244ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_004\merged_snippet_008_5000375_The_human_brain_is_a_predictio.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_004\merged_snippet_008_5000375_The_human_brain_is_a_predictio.txt
#   Saving merged snippet: With enough practice, you can pick up on the cues ... from 5024645ms to 5033593ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_004\merged_snippet_009_5024645_With_enough_practice_you_can_p.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_004\merged_snippet_009_5024645_With_enough_practice_you_can_p.txt
#   Saving merged snippet: We can't always explain what it is we are learning... from 5034707ms to 5044793ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_004\merged_snippet_010_5034707_We_can't_always_explain_what_i.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_004\merged_snippet_010_5034707_We_can't_always_explain_what_i.txt
#   Saving merged snippet: We underestimate how much our brains and bodies ca... from 5045853ms to 5061342ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_004\merged_snippet_011_5045853_We_underestimate_how_much_our_.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_004\merged_snippet_011_5045853_We_underestimate_how_much_our_.txt
#   Saving merged snippet: Consider hunger. How do you know when you are hung... from 5062520ms to 5079785ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_004\merged_snippet_012_5062520_Consider_hunger_How_do_you_kno.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_004\merged_snippet_012_5062520_Consider_hunger_How_do_you_kno.txt
#   Saving merged snippet: Cravings can arise thanks to hormones and chemical... from 5081065ms to 5104409ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_004\merged_snippet_013_5081065_Cravings_can_arise_thanks_to_h.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_004\merged_snippet_013_5081065_Cravings_can_arise_thanks_to_h.txt
#   Saving merged snippet: As habits form, your actions come under the direct... from 5105589ms to 5129702ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_004\merged_snippet_014_5105589_As_habits_form_your_actions_co.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_004\merged_snippet_014_5105589_As_habits_form_your_actions_co.txt
#   Saving merged snippet: I once heard of a retail clerk who was instructed ... from 5130830ms to 5152206ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_004\merged_snippet_015_5130830_I_once_heard_of_a_retail_clerk.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_004\merged_snippet_015_5130830_I_once_heard_of_a_retail_clerk.txt
#   Saving merged snippet: Another woman I came across in my research was a f... from 5153497ms to 5172460ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_004\merged_snippet_016_5153497_Another_woman_I_came_across_in.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_004\merged_snippet_016_5153497_Another_woman_I_came_across_in.txt
#   Saving merged snippet: Over time, the cues that spark our habits can beco... from 5173868ms to 5193296ms
# ...
#   Saving merged snippet: Finally, reflection and review offers an ideal tim... from 19447213ms to 19454198ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_024_19447213_Finally_reflection_and_review_.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_024_19447213_Finally_reflection_and_review_.txt
#   Saving merged snippet: How to break the beliefs that hold you back.... from 19456600ms to 19458582ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_025_19456600_How_to_break_the_beliefs_that_.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_025_19456600_How_to_break_the_beliefs_that_.txt
#   Saving merged snippet: In the beginning, repeating a habit is essential t... from 19459888ms to 19483626ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_026_19459888_In_the_beginning_repeating_a_h.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_026_19459888_In_the_beginning_repeating_a_h.txt
#   Saving merged snippet: The more sacred an idea is to us, that is, the mor... from 19484888ms to 19512788ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_027_19484888_The_more_sacred_an_idea_is_to_.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_027_19484888_The_more_sacred_an_idea_is_to_.txt
#   Saving merged snippet: The tighter we cling to an identity, the harder it... from 19514031ms to 19517855ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_028_19514031_The_tighter_we_cling_to_an_ide.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_028_19514031_The_tighter_we_cling_to_an_ide.txt
#   Saving merged snippet: One solution is to avoid making any single aspect ... from 19519016ms to 19558020ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_029_19519016_One_solution_is_to_avoid_makin.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_029_19519016_One_solution_is_to_avoid_makin.txt
#   Saving merged snippet: For most of my young life, being an athlete was a ... from 19559445ms to 19572249ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_030_19559445_For_most_of_my_young_life_bein.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_030_19559445_For_most_of_my_young_life_bein.txt
#   Saving merged snippet: Military veterans and former entrepreneurs report ... from 19573530ms to 19583273ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_031_19573530_Military_veterans_and_former_e.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_031_19573530_Military_veterans_and_former_e.txt
#   Saving merged snippet: For many business owners, their identity is someth... from 19584403ms to 19590335ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_032_19584403_For_many_business_owners_their.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_032_19584403_For_many_business_owners_their.txt
#   Saving merged snippet: If you have spent every waking moment working on y... from 19591397ms to 19596046ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_033_19591397_If_you_have_spent_every_waking.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_033_19591397_If_you_have_spent_every_waking.txt
#   Saving merged snippet: The key to mitigating these losses of identity is ... from 19597242ms to 19620767ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_034_19597242_The_key_to_mitigating_these_lo.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_034_19597242_The_key_to_mitigating_these_lo.txt
#   Saving merged snippet: I'm the CEO translates to, I'm the type of person ... from 19621907ms to 19626468ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_035_19621907_I'm_the_CEO_translates_to_I'm_.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_035_19621907_I'm_the_CEO_translates_to_I'm_.txt
#   Saving merged snippet: When chosen effectively, an identity can be flexib... from 19627988ms to 19638817ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_036_19627988_When_chosen_effectively_an_ide.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_036_19627988_When_chosen_effectively_an_ide.txt
#   Saving merged snippet: The following quote from the Tao Te Ching encapsul... from 19640158ms to 19643861ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_037_19640158_The_following_quote_from_the_T.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_037_19640158_The_following_quote_from_the_T.txt
#   Saving merged snippet: Men are born soft and supple. Dead, they are stiff... from 19645362ms to 19654590ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_038_19645362_Men_are_born_soft_and_supple_D.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_038_19645362_Men_are_born_soft_and_supple_D.txt
#   Saving merged snippet: Thus, whoever is stiff and inflexible is a discipl... from 19655709ms to 19663534ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_039_19655709_Thus_whoever_is_stiff_and_infl.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_039_19655709_Thus_whoever_is_stiff_and_infl.txt
#   Saving merged snippet: The hard and the stiff will be broken, the soft an... from 19664594ms to 19669237ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_040_19664594_The_hard_and_the_stiff_will_be.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_040_19664594_The_hard_and_the_stiff_will_be.txt
#   Saving merged snippet: Lao Tzu Habits deliver numerous benefits, but the ... from 19670438ms to 19695400ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_041_19670438_Lao_Tzu_Habits_deliver_numerou.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_041_19670438_Lao_Tzu_Habits_deliver_numerou.txt
#   Saving merged snippet: Chapter Summary. The upside of habits is that we c... from 19697661ms to 19710207ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_042_19697661_Chapter_Summary_The_upside_of_.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_042_19697661_Chapter_Summary_The_upside_of_.txt
#   Saving merged snippet: Reflection and review is a process that allows you... from 19711326ms to 19716428ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_043_19711326_Reflection_and_review_is_a_pro.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_043_19711326_Reflection_and_review_is_a_pro.txt
#   Saving merged snippet: The tighter we cling to an identity, the harder it... from 19717569ms to 19721631ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_044_19717569_The_tighter_we_cling_to_an_ide.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_044_19717569_The_tighter_we_cling_to_an_ide.txt
#   Saving merged snippet: Conclusion. The secret to results that last.... from 19726493ms to 19729215ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_045_19726493_Conclusion_The_secret_to_resul.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_045_19726493_Conclusion_The_secret_to_resul.txt
#   Saving merged snippet: There is an ancient Greek parable known as the Sor... from 19732196ms to 19745801ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_046_19732196_There_is_an_ancient_Greek_para.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_046_19732196_There_is_an_ancient_Greek_para.txt
#   Saving merged snippet: If you give a person a pile of 10 coins, you would... from 19746821ms to 19755323ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_047_19746821_If_you_give_a_person_a_pile_of.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_047_19746821_If_you_give_a_person_a_pile_of.txt
#   Saving merged snippet: At some point, you will have to admit that no one ... from 19756543ms to 19762184ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_048_19756543_At_some_point_you_will_have_to.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_048_19756543_At_some_point_you_will_have_to.txt
#   Saving merged snippet: We can say the same about atomic habits. Can one t... from 19763684ms to 19775092ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_049_19763684_We_can_say_the_same_about_atom.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_049_19763684_We_can_say_the_same_about_atom.txt
#   Saving merged snippet: At some point, you will have to admit that your li... from 19776152ms to 19780393ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_050_19776152_At_some_point_you_will_have_to.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_050_19776152_At_some_point_you_will_have_to.txt
#   Saving merged snippet: The holy grail of habit change is not a single 1% ... from 19781634ms to 19786435ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_051_19781634_The_holy_grail_of_habit_change.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_051_19781634_The_holy_grail_of_habit_change.txt
#   Saving merged snippet: It's a bunch of atomic habits stacking up, each on... from 19787495ms to 19792757ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_052_19787495_It's_a_bunch_of_atomic_habits_.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_052_19787495_It's_a_bunch_of_atomic_habits_.txt
#   Saving merged snippet: In the beginning, small improvements can often see... from 19794283ms to 19799708ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_053_19794283_In_the_beginning_small_improve.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_053_19794283_In_the_beginning_small_improve.txt
#   Saving merged snippet: Just as one coin won't make you rich, one positive... from 19800769ms to 19809858ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_054_19800769_Just_as_one_coin_won't_make_yo.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_054_19800769_Just_as_one_coin_won't_make_yo.txt
#   Saving merged snippet: Gradually, though, as you continue to layer small ... from 19810879ms to 19834287ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_055_19810879_Gradually_though_as_you_contin.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_055_19810879_Gradually_though_as_you_contin.txt
#   Saving merged snippet: Over the course of this book, we've looked at doze... from 19835745ms to 19852938ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_056_19835745_Over_the_course_of_this_book_w.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_056_19835745_Over_the_course_of_this_book_w.txt
#   Saving merged snippet: Each of the people, teams, and companies we have c... from 19854176ms to 19865965ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_057_19854176_Each_of_the_people_teams_and_c.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_057_19854176_Each_of_the_people_teams_and_c.txt
#   Saving merged snippet: Success is not a goal to reach or a finish line to... from 19867166ms to 19874252ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_058_19867166_Success_is_not_a_goal_to_reach.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_026\merged_snippet_058_19867166_Success_is_not_a_goal_to_reach.txt
#   Finished processing chunk chunk_026.json. Saved 58 merged snippets.
#
# Processing chunk file: chunk_027.json -> Outputting to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_027
#   Found 8 raw evidence items in this chunk.
#   Saving merged snippet: In chapter one, I said, if you're having trouble c... from 19875365ms to 19888769ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_027\merged_snippet_001_19875365_In_chapter_one_I_said_if_you'r.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_027\merged_snippet_001_19875365_In_chapter_one_I_said_if_you'r.txt
#   Saving merged snippet: With the four laws of behavior change, you have a ... from 19894071ms to 19901413ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_027\merged_snippet_002_19894071_With_the_four_laws_of_behavior.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_027\merged_snippet_002_19894071_With_the_four_laws_of_behavior.txt
#   Saving merged snippet: This is a continuous process. There is no finish l... from 19921045ms to 19941529ms
#     Audio saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_027\merged_snippet_003_19921045_This_is_a_continuous_process_T.mp3
#     Transcript saved to: d:\DATA300\AudioBookSum\output_snippets_by_chunk\chunk_027\merged_snippet_003_19921045_This_is_a_continuous_process_T.txt
#   Finished processing chunk chunk_027.json. Saved 3 merged snippets.
#
# --- Overall Summary ---
# Processed 1152 raw evidence items across all chunks.
# Successfully extracted and saved 652 merged audio snippets and transcripts to respective folders in d:\DATA300\AudioBookSum\output_snippets_by_chunk
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Now we have the snippets, what do we do?
# 1. Load it onto cloud databases for future processes
# 2. Generate an overarching audio summarizing everything
