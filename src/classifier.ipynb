# %%
import cv2      # OpenCV
import numpy as np
import os
import pandas as pd
from typing import List, Tuple, Dict
import matplotlib.pyplot as plt # For visual_proof

# --- Machine Learning Imports ---
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB # Assuming features are somewhat Gaussian
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier # Added
from sklearn.svm import SVC                     # Added
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.utils import shuffle # Import shuffle
from sklearn.model_selection import learning_curve, ShuffleSplit # Added for learning curves
import warnings
import joblib # Added for saving/loading models

warnings.filterwarnings("ignore", category=UserWarning, module='sklearn')
warnings.filterwarnings("ignore", category=RuntimeWarning) # Ignore potential division by zero etc. in numpy if no boxes found

# Type alias for pixel bounding box
PixelBoundingBox = Tuple[int, int, int, int] # (x, y, width, height)
# Import necessary libraries for plotting and analysis
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.metrics import precision_score, recall_score, f1_score
from typing import Dict, Any, Optional

# --- Performance Analysis and Visualization Function ---

def analyze_and_visualize_performance(
    results: Dict[str, Dict[str, Any]],
    label_encoder: Optional[Any] = None, # Pass the fitted LabelEncoder
    baseline_model_name: Optional[str] = None, # e.g., "Logistic Regression" or None to auto-select best accuracy
    dataset_name: str = "Dataset" # Optional name for plot titles
):
    """
    Analyzes and visualizes the performance of multiple classification models.

    Generates:
        1. A bar chart comparing Accuracy, Precision, Recall, and F1-score (macro avg).
        2. Plots of confusion matrices for each model.
        3. Calculates and returns performance differences relative to a baseline model.

    Args:
        results: A dictionary where keys are model names and values are dictionaries
                 containing at least 'accuracy', 'report' (classification_report string),
                 'confusion_matrix' (numpy array), and potentially 'model' object.
                 Expected output format from `run_classification_comparison`.
        label_encoder: The fitted scikit-learn LabelEncoder instance used for the target
                       variable, needed for class names in plots. If None, generic
                       labels ('Class 0', 'Class 1') will be used.
        baseline_model_name: The name of the model to use as a baseline for comparison.
                             If None, the model with the highest accuracy will be chosen.
        dataset_name: An optional name for the dataset to include in plot titles.

    Returns:
        pandas.DataFrame: A DataFrame containing the performance differences
                          (Accuracy, Precision, Recall, F1) for each model
                          relative to the baseline. Returns None if analysis fails.
    """
    print("\n--- Performance Analysis and Visualization ---")

    valid_results = {name: res for name, res in results.items() if res and res.get('confusion_matrix') is not None}

    if not valid_results:
        print("No valid model results found to analyze.")
        return None

    model_names = list(valid_results.keys())
    class_names = ['Class 0', 'Class 1'] # Default if label_encoder is not provided
    if label_encoder and hasattr(label_encoder, 'classes_'):
         if len(label_encoder.classes_) == valid_results[model_names[0]]['confusion_matrix'].shape[0]:
              class_names = label_encoder.classes_
         else:
              print("Warning: LabelEncoder classes don't match confusion matrix dimensions. Using generic labels.")


    # --- 1. Extract Key Metrics ---
    metrics_data = {
        'Model': [],
        'Accuracy': [],
        'Precision (Macro)': [],
        'Recall (Macro)': [],
        'F1-Score (Macro)': []
    }

    for name, res in valid_results.items():
        try:
            # Extract metrics from classification report string (more robust than just accuracy)
            report_dict = classification_report(
                y_true=np.array([]), # Dummy y_true/y_pred needed structure, won't be used
                y_pred=np.array([]), # We only parse the string report provided
                output_dict=True,
                zero_division=0,
                labels=np.arange(len(class_names)), # Ensure correct labels are considered
                target_names=class_names,
                # Hack: Pass the report string itself if available (not standard usage)
                # A better way is to recalculate from y_test, y_pred if available
                # For now, we parse the stored string report if possible, otherwise calculate macro avg from CM
                # Let's recalculate if possible (assuming y_test/y_pred were stored or accessible)
                # If not, we parse the string report (less ideal) or calculate from CM
            )

            # Fallback/Alternative: Calculate macro averages directly from confusion matrix
            cm = res['confusion_matrix']
            if cm.shape[0] != cm.shape[1]:
                 print(f"Warning: Non-square confusion matrix for {name}. Skipping metric calculation.")
                 continue

            tp = np.diag(cm)
            fp = cm.sum(axis=0) - tp # Sum down column (predicted positive) - true positives
            fn = cm.sum(axis=1) - tp # Sum across row (actual positive) - true positives
            # tn = cm.sum() - (fp + fn + tp) # Not directly needed for macro precision/recall

            # Per-class precision and recall (handle division by zero)
            precision_per_class = tp / (tp + fp)
            recall_per_class = tp / (tp + fn)
            f1_per_class = 2 * (precision_per_class * recall_per_class) / (precision_per_class + recall_per_class)

            # Replace NaNs resulting from division by zero (e.g., class never predicted)
            precision_per_class = np.nan_to_num(precision_per_class)
            recall_per_class = np.nan_to_num(recall_per_class)
            f1_per_class = np.nan_to_num(f1_per_class)

            macro_precision = np.mean(precision_per_class)
            macro_recall = np.mean(recall_per_class)
            macro_f1 = np.mean(f1_per_class) # Macro F1 is average of per-class F1

            metrics_data['Model'].append(name)
            metrics_data['Accuracy'].append(res['accuracy']) # Accuracy is usually overall
            metrics_data['Precision (Macro)'].append(macro_precision)
            metrics_data['Recall (Macro)'].append(macro_recall)
            metrics_data['F1-Score (Macro)'].append(macro_f1)

        except Exception as e:
            print(f"Warning: Could not parse or calculate detailed metrics for {name}. Error: {e}")
            # Add placeholders if parsing fails but accuracy exists
            if 'accuracy' in res:
                 metrics_data['Model'].append(name)
                 metrics_data['Accuracy'].append(res['accuracy'])
                 metrics_data['Precision (Macro)'].append(np.nan)
                 metrics_data['Recall (Macro)'].append(np.nan)
                 metrics_data['F1-Score (Macro)'].append(np.nan)


    metrics_df = pd.DataFrame(metrics_data)
    if metrics_df.empty:
         print("Could not extract metrics for any model.")
         return None

    print("\n--- Comparative Metrics (Macro Averages) ---")
    print(metrics_df.to_string(index=False))

    # --- 2. Plot Key Metrics Comparison ---
    try:
        plt.style.use('seaborn-v0_8-darkgrid') # Use a nice style
        metrics_to_plot = ['Accuracy', 'Precision (Macro)', 'Recall (Macro)', 'F1-Score (Macro)']
        plot_df = metrics_df.melt(id_vars='Model', var_name='Metric', value_name='Score', value_vars=metrics_to_plot)

        plt.figure(figsize=(14, 8)) # Adjusted figure size for more models
        bar_plot = sns.barplot(data=plot_df, x='Model', y='Score', hue='Metric', palette='viridis')

        plt.title(f'Model Performance Comparison ({dataset_name}) - Macro Averages', fontsize=16)
        plt.xlabel("Model", fontsize=12)
        plt.ylabel("Score", fontsize=12)
        plt.xticks(rotation=25, ha='right') # Increased rotation slightly
        plt.ylim(0, 1.05) # Scores are typically between 0 and 1
        plt.legend(title='Metric', bbox_to_anchor=(1.02, 1), loc='upper left')

        # Add score labels on top of bars
        for container in bar_plot.containers:
            bar_plot.bar_label(container, fmt='%.3f', fontsize=9, padding=3)

        plt.tight_layout(rect=[0, 0, 0.85, 1]) # Adjust layout to make space for legend
        plt.show()
    except Exception as e:
        print(f"Error generating metrics comparison plot: {e}")


    # --- 3. Plot Confusion Matrices ---
    num_models = len(valid_results)
    # Adjust layout based on number of models
    ncols = min(num_models, 3) # Max 3 columns
    nrows = (num_models + ncols - 1) // ncols # Calculate rows needed

    if num_models > 0:
        try:
            fig_cm, axes = plt.subplots(nrows, ncols, figsize=(ncols * 5, nrows * 4.5), squeeze=False)
            axes = axes.flatten() # Flatten the axes array for easy iteration

            for i, (name, res) in enumerate(valid_results.items()):
                cm = res['confusion_matrix']
                if cm is None:
                    # Optionally plot an empty placeholder or text
                    axes[i].text(0.5, 0.5, 'No CM data', horizontalalignment='center', verticalalignment='center', transform=axes[i].transAxes)
                    axes[i].set_title(f"{name}\n(No Data)", fontsize=12)
                    axes[i].axis('off')
                    continue

                sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=axes[i],
                            xticklabels=class_names, yticklabels=class_names,
                            annot_kws={"size": 12}) # Increase annotation font size
                axes[i].set_title(f"Confusion Matrix: {name}", fontsize=14)
                axes[i].set_xlabel("Predicted Label", fontsize=11)
                axes[i].set_ylabel("True Label", fontsize=11)
                axes[i].tick_params(axis='x', rotation=0) # Keep x-axis labels horizontal
                axes[i].tick_params(axis='y', rotation=0)

            # Hide any unused subplots
            for j in range(i + 1, len(axes)):
                fig_cm.delaxes(axes[j])

            fig_cm.suptitle(f'Confusion Matrices ({dataset_name})', fontsize=18, y=1.03) # Add overall title
            plt.tight_layout(rect=[0, 0, 1, 0.97]) # Adjust layout for suptitle
            plt.show()
        except Exception as e:
            print(f"Error generating confusion matrix plots: {e}")

    # --- 4. Calculate Performance Differences ---
    if baseline_model_name is None or baseline_model_name not in metrics_df['Model'].values:
        # Auto-select baseline: model with highest accuracy
        baseline_model_name = metrics_df.loc[metrics_df['Accuracy'].idxmax()]['Model'] if not metrics_df.empty else None
        if baseline_model_name:
             print(f"\nUsing '{baseline_model_name}' (highest accuracy) as baseline for comparison.")
        else:
             print("Could not determine baseline model.")
             return None # Cannot calculate differences without a baseline
    elif baseline_model_name not in metrics_df['Model'].values:
         print(f"Error: Specified baseline model '{baseline_model_name}' not found in results. Cannot calculate differences.")
         return None
    else:
         print(f"\nUsing '{baseline_model_name}' as baseline for comparison.")


    baseline_metrics = metrics_df[metrics_df['Model'] == baseline_model_name].iloc[0]
    diff_data = {'Model': []}
    metrics_for_diff = [col for col in metrics_df.columns if col != 'Model'] # Get all metric columns
    for metric in metrics_for_diff:
        diff_data[f'{metric} Diff'] = []

    for i, row in metrics_df.iterrows():
        if row['Model'] == baseline_model_name:
            continue # Skip comparison with self

        diff_data['Model'].append(row['Model'])
        for metric in metrics_for_diff:
             diff = row[metric] - baseline_metrics[metric]
             diff_data[f'{metric} Diff'].append(diff)

    diff_df = pd.DataFrame(diff_data)

    if not diff_df.empty:
        print(f"\n--- Performance Difference from Baseline ({baseline_model_name}) ---")
        # Format the difference columns to show +/- signs explicitly
        for col in diff_df.columns:
             if 'Diff' in col:
                 diff_df[col] = diff_df[col].map('{:+.4f}'.format) # Format with sign and 4 decimal places
        print(diff_df.to_string(index=False))

        # --- Optional: Plot Differences ---
        try:
             plot_diff_df = pd.DataFrame(diff_data) # Use the original numeric diff_data
             plot_diff_df = plot_diff_df.melt(id_vars='Model', var_name='Metric Difference', value_name='Difference')

             plt.figure(figsize=(14, 8)) # Adjusted figure size
             diff_bar_plot = sns.barplot(data=plot_diff_df, x='Model', y='Difference', hue='Metric Difference', palette='coolwarm') # Use diverging palette

             plt.title(f'Performance Difference from Baseline ({baseline_model_name})', fontsize=16)
             plt.xlabel("Model", fontsize=12)
             plt.ylabel("Difference in Score", fontsize=12)
             plt.xticks(rotation=25, ha='right') # Adjusted rotation
             plt.axhline(0, color='grey', linewidth=0.8, linestyle='--') # Line at zero difference
             plt.legend(title='Metric Diff.', bbox_to_anchor=(1.02, 1), loc='upper left')

             # Add score labels on top of bars
             for container in diff_bar_plot.containers:
                 diff_bar_plot.bar_label(container, fmt='%.3f', fontsize=9, padding=3)

             plt.tight_layout(rect=[0, 0, 0.85, 1]) # Adjust layout for legend
             plt.show()
        except Exception as e:
             print(f"Error generating performance difference plot: {e}")

    else:
        print("No models to compare against the baseline.")
        return None # Return None if diff_df is empty

    # Return the numeric difference dataframe (before formatting for printing)
    return pd.DataFrame(diff_data)

# --- Bounding Box Merging (Pixel Coordinates) ---
def merge_pixel_regions(boxes: List[PixelBoundingBox],
                         overlap_threshold: float = 0.1, # Min intersection/smaller_area ratio
                         iterations: int = 3) -> List[PixelBoundingBox]:
    """
    Merges overlapping or very close bounding boxes iteratively.
    Operates on (x, y, w, h) tuples.
    """
    if len(boxes) <= 1:
        return boxes

    current_boxes = list(boxes)
    for _ in range(iterations):
        merged_in_pass = False
        merged_boxes = []
        used = [False] * len(current_boxes)

        # Sort boxes to potentially improve efficiency (top-to-bottom, left-to-right)
        current_boxes.sort(key=lambda b: (b[1], b[0]))

        for i in range(len(current_boxes)):
            if used[i]:
                continue

            base_box = list(current_boxes[i]) # Use list for modification
            base_x, base_y, base_w, base_h = base_box
            base_x1, base_y1 = base_x + base_w, base_y + base_h
            base_area = base_w * base_h

            used[i] = True
            did_merge = True # Flag to check if this specific box merged with others

            while did_merge: # Keep merging with the current base_box until no more overlaps found
                 did_merge = False
                 for j in range(i + 1, len(current_boxes)):
                    if not used[j]:
                        other_box = current_boxes[j]
                        other_x, other_y, other_w, other_h = other_box
                        other_x1, other_y1 = other_x + other_w, other_y + other_h
                        other_area = other_w * other_h

                        # Check for overlap (intersection)
                        inter_x0 = max(base_x, other_x)
                        inter_y0 = max(base_y, other_y)
                        inter_x1 = min(base_x1, other_x1)
                        inter_y1 = min(base_y1, other_y1)

                        inter_w = inter_x1 - inter_x0
                        inter_h = inter_y1 - inter_y0

                        if inter_w > 0 and inter_h > 0: # They overlap
                            intersection_area = inter_w * inter_h
                            smaller_area = min(base_area, other_area) if min(base_area, other_area) > 0 else 1e-6

                            # Merge if intersection area is significant relative to smaller box
                            if intersection_area / smaller_area >= overlap_threshold:
                                # Calculate union box
                                union_x0 = min(base_x, other_x)
                                union_y0 = min(base_y, other_y)
                                union_x1 = max(base_x1, other_x1)
                                union_y1 = max(base_y1, other_y1)

                                # Update base_box to the union
                                base_box = [union_x0, union_y0, union_x1 - union_x0, union_y1 - union_y0]
                                base_x, base_y, base_w, base_h = base_box # Update values for next check
                                base_x1, base_y1 = base_x + base_w, base_y + base_h
                                base_area = base_w * base_h

                                used[j] = True
                                merged_in_pass = True
                                did_merge = True # Mark that this base_box grew
                                # Continue checking other boxes against the *new* larger base_box

                 # End of inner loop (checking against other boxes)
                 # If did_merge is True here, the while loop repeats for the current base_box

            merged_boxes.append(tuple(base_box)) # Add the final merged box for index i

        current_boxes = merged_boxes
        if not merged_in_pass: # If no merges happened in a full pass, stop early
            break

    return current_boxes


# --- Contour/Region Extraction from Image ---
def extract_regions_from_image(
    image_path: str,
    adaptive_thresh_block_size: int = 13, # Must be odd > 1 - Adjusted for potentially different image characteristics
    adaptive_thresh_c: int = 2,         # Adjusted C
    morph_kernel_size: tuple = (8, 3), # Rectangular kernel might be better for text lines
    dilate_iterations: int = 2,         # More dilation might be needed
    min_region_width_px: int = 8,      # Min width in pixels
    min_region_height_px: int = 8,     # Min height in pixels
    merge_iterations: int = 3,
    visual_proof: bool = False
) -> Tuple[List[PixelBoundingBox], int, int]:
    """
    Extracts bounding boxes of text-like regions directly from an image file using OpenCV.

    Args:
        image_path: Path to the input PNG image.
        ... (other parameters for OpenCV processing) ...
        visual_proof: If True, displays intermediate images.

    Returns:
        A tuple containing:
        - List of bounding boxes [(x, y, w, h), ...] in pixel coordinates.
        - Image width in pixels.
        - Image height in pixels.
        Returns ([], 0, 0) on failure.
    """
    try:
        img = cv2.imread(image_path)
        if img is None:
            print(f"  Error: Could not read image {image_path}")
            return [], 0, 0
        img_h, img_w = img.shape[:2]
    except Exception as e:
        print(f"  Error loading image {image_path}: {e}")
        return [], 0, 0

    # 1. Preprocessing
    if len(img.shape) == 3 and img.shape[2] == 3:
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    elif len(img.shape) == 2:
        gray = img
    else:
        print(f"  Error: Unsupported image shape {img.shape} for {image_path}")
        return [], img_w, img_h # Return dims even on failure?

    # Invert: Assume dark text on light background common in documents
    # Process expects white features on black background
    gray_inverted = cv2.bitwise_not(gray)

    # 2. Adaptive Thresholding
    adaptive = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                     cv2.THRESH_BINARY_INV, adaptive_thresh_block_size, adaptive_thresh_c)
    # Morphological operations to connect characters/words into text block shapes
    rectKernel = cv2.getStructuringElement(cv2.MORPH_RECT, morph_kernel_size)
    # Dilate to make text regions larger and connect nearby components
    dilated = cv2.dilate(adaptive, rectKernel, iterations=dilate_iterations)
    # Closing to fill small gaps within text regions
    closing = cv2.morphologyEx(dilated, cv2.MORPH_CLOSE, rectKernel)
    # Canny edge detection (sometimes helps refine contours, applied on the closed image)
    edged = cv2.Canny(closing, 50, 200, apertureSize=3)
    # Find external contours on the edge map
    contours, _ = cv2.findContours(edged, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    # print(f"  Found {len(contours)} initial contours.") # Debug

    # 5. Create Initial Regions (Pixel BBoxes) & Pre-filter
    initial_regions = []
    if contours is None:
        contours = []

    for cnt in contours:
        x, y, w, h = cv2.boundingRect(cnt)
        # Basic filtering based on size
        if w >= min_region_width_px / 2 and h >= min_region_height_px / 2: # Looser filter before merge
            initial_regions.append((x, y, w, h))

    # print(f"  Created {len(initial_regions)} initial regions after pre-filtering.") # Debug

    # 6. Merge Overlapping/Nearby Regions
    merged_regions = merge_pixel_regions(initial_regions, iterations=merge_iterations)

    # 7. Final Filtering
    final_regions = [r for r in merged_regions
                     if r[2] >= min_region_width_px and r[3] >= min_region_height_px]

    # Sort final regions by approx reading order (top-to-bottom, left-to-right)
    final_regions.sort(key=lambda r: (r[1], r[0]))

    print(f"  Detected {len(final_regions)} final regions for {os.path.basename(image_path)}.")

    # --- Optional Visual Proof ---
    if visual_proof:
        try:
            viz_img = img.copy()
            # Draw intermediate steps if needed
            plt.figure(figsize=(15, 10))

            plt.subplot(1, 3, 1)
            plt.imshow(adaptive, cmap='gray')
            plt.title("Thresholded")
            plt.axis('off')

            plt.subplot(1, 3, 2)
            plt.imshow(edged, cmap='gray')
            plt.title("Edged")
            plt.axis('off')

            # Draw final detected regions on original image
            for (x, y, w, h) in final_regions:
                cv2.rectangle(viz_img, (x, y), (x + w, y + h), (0, 255, 0), 2) # Green boxes

            plt.subplot(1, 3, 3)
            # Convert BGR (OpenCV) to RGB (matplotlib)
            plt.imshow(cv2.cvtColor(viz_img, cv2.COLOR_BGR2RGB))
            plt.title(f"Detected Regions ({len(final_regions)} blocks)")
            plt.axis('off')

            plt.suptitle(f"Processing: {os.path.basename(image_path)}")
            plt.tight_layout(rect=[0, 0.03, 1, 0.95]) # Adjust layout for suptitle
            plt.show()
        except Exception as e:
            print(f"  Error generating visual proof: {e}")

    return final_regions, img_w, img_h


# --- Feature Engineering (from Pixel Boxes) ---
def extract_features_from_pixel_boxes(boxes: List[PixelBoundingBox], img_width: int, img_height: int) -> Dict[str, float]:
    """
    Calculates features based on the list of detected pixel bounding boxes (x, y, w, h).
    """
    features = {
        'num_blocks': 0.0,
        'median_width': 0.0,
        'std_width': 0.0,
        'median_height': 0.0,
        'std_height': 0.0,
        'median_x_center': 0.0,
        'std_x_center': 0.0,
        'median_y_center': 0.0,
        'std_y_center': 0.0,
        'total_width_ratio': 0.0, 
        'median_aspect_ratio': 0.0,
        'norm_median_width': 0.0,
        'norm_std_x_center': 0.0,
    }

    if not boxes or img_width <= 0 or img_height <= 0:
        return features

    widths = [float(b[2]) for b in boxes]
    heights = [float(b[3]) for b in boxes]
    x_centers = [float(b[0]) + float(b[2]) / 2.0 for b in boxes]
    y_centers = [float(b[1]) + float(b[3]) / 2.0 for b in boxes]
    aspect_ratios = [float(b[2]) / float(b[3]) if b[3] > 0 else 0 for b in boxes]

    features['num_blocks'] = float(len(boxes))
    features['median_width'] = np.median(widths) if widths else 0.0
    features['std_width'] = np.std(widths) if widths else 0.0
    features['median_height'] = np.median(heights) if heights else 0.0
    features['std_height'] = np.std(heights) if heights else 0.0
    features['median_x_center'] = np.median(x_centers) if x_centers else 0.0
    features['std_x_center'] = np.std(x_centers) if x_centers else 0.0
    features['median_y_center'] = np.median(y_centers) if y_centers else 0.0
    features['std_y_center'] = np.std(y_centers) if y_centers else 0.0
    features['total_width_ratio'] = sum(widths) / float(img_width) if img_width > 0 else 0.0
    features['median_aspect_ratio'] = np.median(aspect_ratios) if aspect_ratios else 0.0

    # Normalized features
    features['norm_median_width'] = features['median_width'] / float(img_width) if img_width > 0 else 0.0
    features['norm_std_x_center'] = features['std_x_center'] / float(img_width) if img_width > 0 else 0.0

    return features

# --- Data Loading and Processing from CSV ---
def load_and_process_images_from_csv(csv_path: str, image_path_col: str, label_col: str, visualize_indexes: List[int] = [-1]) -> pd.DataFrame:
    """
    Loads image paths and labels from a CSV, extracts regions, calculates features,
    and returns a DataFrame.

    Args:
        csv_path: Path to the CSV file.
        image_path_col: Name of the column containing image paths.
        label_col: Name of the column containing labels.
        visualize_index: Row index (0-based) in the CSV to visualize processing for.

    Returns:
        A pandas DataFrame with features and labels. Returns empty DataFrame on error.
    """
    try:
        df_input = pd.read_csv(csv_path)
        if image_path_col not in df_input.columns or label_col not in df_input.columns:
             print(f"Error: CSV must contain columns named '{image_path_col}' and '{label_col}'")
             return pd.DataFrame()
        print(f"Loaded {len(df_input)} entries from {csv_path}")
    except FileNotFoundError:
        print(f"Error: CSV file not found at {csv_path}")
        return pd.DataFrame()
    except Exception as e:
        print(f"Error reading CSV {csv_path}: {e}")
        return pd.DataFrame()

    all_features = []
    base_dir = os.path.dirname(csv_path) # Assume relative paths are relative to the CSV

    for index, row in df_input.iterrows():
        image_file = row[image_path_col]
        label = row[label_col]

        # Construct full path (handle relative paths)
        if not os.path.isabs(image_file):
             image_path = os.path.join(base_dir, image_file)
        else:
             image_path = image_file

        print(f"\nProcessing image {index+1}/{len(df_input)}: {os.path.basename(image_path)} (Label: {label})")

        if not os.path.exists(image_path):
             print(f"  Warning: Image file not found at {image_path}. Skipping.")
             continue

        show_visual = (index in visualize_indexes)

        # Extract regions (bounding boxes) and image dimensions
        boxes, img_w, img_h = extract_regions_from_image(image_path, visual_proof=show_visual)

        if img_w == 0 or img_h == 0:
             print(f"  Warning: Could not get valid dimensions for {image_path}. Skipping feature extraction.")
             continue

        # Calculate features from the detected boxes
        page_features = extract_features_from_pixel_boxes(boxes, img_w, img_h)

        # Add metadata
        page_features['image_path'] = image_file # Store original path from CSV
        page_features['label'] = label
        all_features.append(page_features)

    return pd.DataFrame(all_features)


# --- Main Machine Learning Pipeline ---
def run_classification_comparison(data_df: pd.DataFrame):
    """
    Trains and evaluates the specified classifiers.
    Includes KNN tuning by plotting accuracy vs. K.
    Generates learning curves for each model.
    Returns results, the label encoder, the scaler, and the test data.
    """
    if data_df.empty or 'label' not in data_df.columns:
        print("Feature DataFrame is empty or missing 'label' column. Cannot train models.")
        return None, None, None, None, None

    if data_df['label'].nunique() < 2:
        print(f"Error: Only found {data_df['label'].nunique()} 1 unique labels. Need at least 2 for classification.")
        return None, None, None, None, None

    # --- Shuffle the data ---
    # Shuffle the DataFrame rows randomly before splitting.
    # Using random_state ensures reproducibility if needed.
    data_df_shuffled = shuffle(data_df, random_state=42)
    print("\nData shuffled before splitting.")

    # Prepare data for Scikit-learn using the shuffled DataFrame
    feature_cols = [col for col in data_df_shuffled.columns if col not in ['image_path', 'label']]
    X = data_df_shuffled[feature_cols].copy()
    y_raw = data_df_shuffled['label']

    # Handle potential NaN/inf values resulting from feature extraction
    X.replace([np.inf, -np.inf], np.nan, inplace=True)
    X.fillna(0.0, inplace=True) # Simple imputation: fill NaNs with 0 (consider alternatives like median)

    # Encode labels
    le = LabelEncoder()
    y = le.fit_transform(y_raw)
    label_mapping = dict(zip(le.classes_, range(len(le.classes_))))
    print(f"\nLabels mapped: {label_mapping}")

    # Check if enough samples for stratified split
    min_samples_per_class = np.min(np.bincount(y))
    test_size = 0.2
    n_splits = int(1 / test_size) if test_size > 0 else 1

    if min_samples_per_class < n_splits and min_samples_per_class > 0:
         print(f"\nWarning: The smallest class has only {min_samples_per_class} samples.")
         print(f"Adjusting test_size for stratification or consider getting more data.")
         # Adjust test size if possible, or don't stratify
         if min_samples_per_class <= 1:
             print("Cannot stratify with only 1 sample in a class. Splitting without stratify.")
             X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42, stratify=None)
         else:
             # Try reducing test size to keep at least 1 sample in test set for each class
             new_test_size = 1.0 / min_samples_per_class if min_samples_per_class > 1 else 0.1 # Ensure test has at least one
             test_size = max(0.1, min(test_size, new_test_size - 0.01)) # Keep at least 10% test, don't make it too big
             print(f"Using adjusted test_size: {test_size:.2f}")
             X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42, stratify=y)

    elif min_samples_per_class == 0:
         print("Error: A class has zero samples after potential filtering. Cannot train.")
         return None, None, None, None, None
    else:
         # Standard split
         X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=42, stratify=y)


    print(f"Training data shape: {X_train.shape}")
    print(f"Testing data shape: {X_test.shape}")


    # Scale features (important for LogReg, KNN, SVM)
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # --- KNN Tuning: Find optimal K and plot Accuracy vs. K ---
    # Note: KNN is an instance-based learner and does not have 'epochs' like iterative models.
    # Instead, we tune the hyperparameter 'K' (number of neighbors).
    print("\n--- KNN Tuning (Accuracy vs. K) ---")
    k_range = range(2, 16) # Test K values from 1 to 15
    k_accuracies = []
    best_k = 5 # Default K
    best_k_accuracy = 0.0

    for k in k_range:
        try:
            knn_tune = KNeighborsClassifier(n_neighbors=k)
            knn_tune.fit(X_train_scaled, y_train)
            y_pred_tune = knn_tune.predict(X_test_scaled)
            accuracy = accuracy_score(y_test, y_pred_tune)
            k_accuracies.append(accuracy)
            if accuracy > best_k_accuracy:
                best_k_accuracy = accuracy
                best_k = k
        except Exception as e:
            print(f"  Error during KNN tuning for K={k}: {e}")
            k_accuracies.append(0.0) # Append 0 accuracy on error

    # Plot K vs. Accuracy
    try:
        plt.figure(figsize=(10, 6))
        plt.plot(k_range, k_accuracies, marker='o', linestyle='-', color='b')
        plt.title('KNN Performance: Accuracy vs. Number of Neighbors (K)')
        plt.xlabel('Number of Neighbors (K)')
        plt.ylabel('Accuracy on Test Set')
        plt.xticks(k_range)
        plt.grid(True)
        # Highlight the best K
        if best_k_accuracy > 0:
             plt.scatter(best_k, best_k_accuracy, color='red', s=100, zorder=5, label=f'Best K={best_k} (Acc: {best_k_accuracy:.3f})')
             plt.legend()
        plt.show()
        print(f"Best K found: {best_k} with accuracy: {best_k_accuracy:.4f}")
    except Exception as e:
        print(f"Error plotting K vs. Accuracy: {e}")
    print("-" * 30)
    # --- End KNN Tuning ---

    # Define models (Using the best K found for KNN)
    models = {
        "Logistic Regression": LogisticRegression(random_state=42, max_iter=1000, class_weight='balanced'),
        f"K-Nearest Neighbors (K={best_k})": KNeighborsClassifier(n_neighbors=best_k), # Use best K found
        "Gaussian Naive Bayes": GaussianNB(),
        "Decision Tree": DecisionTreeClassifier(random_state=42, class_weight='balanced'),
        "Random Forest": RandomForestClassifier(random_state=42, class_weight='balanced', n_estimators=100),
        "Support Vector Machine (SVM)": SVC(random_state=42, class_weight='balanced', probability=True)
    }

    results = {}

    # Define cross-validation strategy for learning curves
    # ShuffleSplit is a good choice for potentially large datasets
    cv = ShuffleSplit(n_splits=10, test_size=0.2, random_state=42)

    # Train and evaluate each model
    print("\n--- Model Training, Evaluation, and Learning Curves ---")
    for name, model in models.items():
        print(f"\nTraining {name}...")
        # Use scaled data for consistency (NB/DT less sensitive, but won't hurt)
        try:
             model.fit(X_train_scaled, y_train)
             y_pred = model.predict(X_test_scaled)
             y_pred_proba = None
             if hasattr(model, "predict_proba"):
                 y_pred_proba = model.predict_proba(X_test_scaled)[:, 1] # Probability for positive class

             accuracy = accuracy_score(y_test, y_pred)
             report = classification_report(y_test, y_pred, target_names=le.classes_, zero_division=0)
             cm = confusion_matrix(y_test, y_pred)

             results[name] = {'accuracy': accuracy, 'report': report, 'confusion_matrix': cm, 'model': model}

             print(f"\n--- {name} Results ---")
             print(f"Accuracy: {accuracy:.4f}")
             print("Classification Report:")
             print(report)
             print("Confusion Matrix:")
             print(f"Predicted: {le.classes_[0]} {le.classes_[1]}") # Show labels for CM axes
             print(f"Actual {le.classes_[0]}:    {cm[0]}")
             print(f"Actual {le.classes_[1]}:    {cm[1]}")
             print("-" * (len(name) + 14)) # Separator

             # --- Generate and Plot Learning Curve ---
             print(f"Generating Learning Curve for {name}...")
             train_sizes, train_scores, valid_scores = learning_curve(
                 model, X_train_scaled, y_train, cv=cv, n_jobs=-1,
                 train_sizes=np.linspace(0.1, 1.0, 10), # Use 10 points from 10% to 100% of training data
                 scoring='accuracy' # Use accuracy for the curve
             )

             # Calculate mean and standard deviation for training and validation scores
             train_scores_mean = np.mean(train_scores, axis=1)
             train_scores_std = np.std(train_scores, axis=1)
             valid_scores_mean = np.mean(valid_scores, axis=1)
             valid_scores_std = np.std(valid_scores, axis=1)

             # Plot the learning curve
             plt.figure(figsize=(10, 6))
             plt.title(f"Learning Curve: {name}")
             plt.xlabel("Training examples")
             plt.ylabel("Accuracy Score")
             plt.grid(True)

             plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                              train_scores_mean + train_scores_std, alpha=0.1,
                              color="r")
             plt.fill_between(train_sizes, valid_scores_mean - valid_scores_std,
                              valid_scores_mean + valid_scores_std, alpha=0.1, color="g")

             plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
                      label="Training score")
             plt.plot(train_sizes, valid_scores_mean, 'o-', color="g",
                      label="Cross-validation score")

             plt.legend(loc="best")
             plt.ylim(0.0, 1.05) # Set y-axis limits for score
             plt.show()
             # --- End Learning Curve ---

        except Exception as e:
             print(f"  ERROR training or evaluating {name}: {e}")
             results[name] = {'accuracy': 0.0, 'report': 'Error', 'confusion_matrix': None, 'model': None}


    # Return test data as well for inference example
    return results, le, scaler, X_test_scaled, y_test

# --- Example Usage ---
if __name__ == "__main__":
    # --- Configuration ---
    # IMPORTANT: Set the path to your CSV file
    CSV_FILE_PATH = r"D:\DATA300\AudioBookSum\src\document_classifications_with_paths.csv" # <--- UPDATE THIS

    # IMPORTANT: Set the names of the columns in your CSV
    IMAGE_PATH_COLUMN = "image_path" # Column with paths to PNGs
    LABEL_COLUMN = "classification"       # Column with 'single_column' or 'multi_column'

    # Set to a list of row indices (e.g., [0, 1, 2]) to visualize processing for those specific image entries.
    # Set to [] or None to disable visualization.
    VISUALIZE_ROW_INDICES = [] # e.g., set to [0, 5, 10] to visualize the first, sixth, and eleventh images

    # --- Run the process ---
    # 1. Load Images from CSV and Extract Features
    feature_data = load_and_process_images_from_csv(
        csv_path=CSV_FILE_PATH,
        image_path_col=IMAGE_PATH_COLUMN,
        label_col=LABEL_COLUMN,
        visualize_indexes=VISUALIZE_ROW_INDICES
    )

    # Save features (optional)
    if not feature_data.empty:
         try:
             output_feature_csv = "image_layout_features.csv"
             feature_data.to_csv(output_feature_csv, index=False)
             print(f"\nFeatures saved to {output_feature_csv}")
         except Exception as e:
             print(f"Error saving features to CSV: {e}")


         # 2. Run ML Comparison
         ml_results, label_encoder, feature_scaler, X_test_scaled, y_test = run_classification_comparison(feature_data)

         # 3. Analyze results and Save Best Model
         best_model = None
         best_model_name = None
         if ml_results:
              print("\nClassification comparison complete.")
              # Find best model by accuracy
              valid_accuracies = {name: res['accuracy'] for name, res in ml_results.items() if res and res['accuracy'] is not None}
              if valid_accuracies:
                  best_model_name = max(valid_accuracies, key=valid_accuracies.get)
                  best_model_accuracy = valid_accuracies[best_model_name]
                  best_model = ml_results[best_model_name]['model']
                  print(f"Best model based on Accuracy: {best_model_name} ({best_model_accuracy:.4f})")
                  base = r"D:\DATA300\AudioBookSum\src\saved_model\"
                  # Save the best model, scaler, and label encoder
                  if best_model and feature_scaler and label_encoder:
                      model_filename = base+ f"best_classifier_model.joblib"
                      scaler_filename = base+f"feature_scaler.joblib"
                      encoder_filename = base+f"label_encoder.joblib"
                      try:
                          joblib.dump(best_model, model_filename)
                          joblib.dump(feature_scaler, scaler_filename)
                          joblib.dump(label_encoder, encoder_filename)
                          print(f"Saved best model to: {model_filename}")
                          print(f"Saved feature scaler to: {scaler_filename}")
                          print(f"Saved label encoder to: {encoder_filename}")
                      except Exception as e:
                          print(f"Error saving model/scaler/encoder: {e}")
                  else:
                      print("Could not save model components (missing model, scaler, or encoder).")
              else:
                  print("Could not determine best model due to errors or no valid accuracy scores.")
         else:
              print("\nClassification comparison could not be completed.")

         # 4. Performance Visualization
         if ml_results and label_encoder:
             performance_differences = analyze_and_visualize_performance(
                 results=ml_results,
                 label_encoder=label_encoder,
                 baseline_model_name=best_model_name, 
                 dataset_name="Document Column Classification"
             )
             if performance_differences is not None:
                 print("\nPerformance difference analysis complete.")
             else:
                 print("\nPerformance difference analysis failed.")
         else:
             print("\nSkipping performance visualization (missing results or label encoder).")

         # 5. Demonstrate Loading and Inference (using test data as example)
         print("\n--- Loading Model and Running Inference Example ---")
         try:
             # Load the saved components
             loaded_model = joblib.load(model_filename)
             loaded_scaler = joblib.load(scaler_filename)
             loaded_encoder = joblib.load(encoder_filename)
             print("Successfully loaded model, scaler, and encoder.")

             # Example: Predict on the first instance of the test set
             if X_test_scaled is not None and len(X_test_scaled) > 0:
                 sample_features_scaled = X_test_scaled[0].reshape(1, -1)
                 prediction_encoded = loaded_model.predict(sample_features_scaled)
                 prediction_label = loaded_encoder.inverse_transform(prediction_encoded)

                 print(f"\nExample Prediction on first test sample:")
                 # print(f"  Scaled Features: {sample_features_scaled}")
                 print(f"  Predicted Encoded Label: {prediction_encoded[0]}")
                 print(f"  Predicted Decoded Label: {prediction_label[0]}")

                 # Compare with actual label if available
                 if y_test is not None and len(y_test) > 0:
                     actual_encoded = y_test[0]
                     actual_label = loaded_encoder.inverse_transform([actual_encoded])
                     print(f"  Actual Label: {actual_label[0]} (Encoded: {actual_encoded})")
             else:
                 print("Test data not available for inference example.")

         except FileNotFoundError:
             print(f"Error: Could not find saved model/scaler/encoder files. Ensure they were saved correctly.")
         except Exception as e:
             print(f"Error during model loading or inference: {e}")

    else:
         print("\nNo features were extracted from the images. Cannot proceed with classification.")
         print(f"Please check the CSV file path ('{CSV_FILE_PATH}'), column names, image paths within the CSV, and image file integrity.")
# Out:
# Loaded 2249 entries from D:\DATA300\AudioBookSum\src\document_classifications_with_paths.csv
#
# Processing image 1/2249: 04_29_19_page_1.png (Label: multicolumn)
#   Detected 4 final regions for 04_29_19_page_1.png.
#
# Processing image 2/2249: 04_29_19_page_2.png (Label: single column)
#   Detected 4 final regions for 04_29_19_page_2.png.
#
# Processing image 3/2249: 04_29_19_page_3.png (Label: single column)
#   Detected 4 final regions for 04_29_19_page_3.png.
#
# Processing image 4/2249: 04_29_19_page_4.png (Label: single column)
#   Detected 4 final regions for 04_29_19_page_4.png.
#
# Processing image 5/2249: 04_29_19_page_5.png (Label: single column)
#   Detected 4 final regions for 04_29_19_page_5.png.
#
# Processing image 6/2249: 04_29_19_page_6.png (Label: single column)
#   Detected 4 final regions for 04_29_19_page_6.png.
#
# Processing image 7/2249: 04_29_19_page_7.png (Label: single column)
#   Detected 4 final regions for 04_29_19_page_7.png.
#
# Processing image 8/2249: 04_29_19_page_8.png (Label: single column)
#   Detected 4 final regions for 04_29_19_page_8.png.
#
# Processing image 9/2249: 04_29_19_page_9.png (Label: single column)
#   Detected 4 final regions for 04_29_19_page_9.png.
#
# Processing image 10/2249: 04_29_19_page_10.png (Label: single column)
#   Detected 4 final regions for 04_29_19_page_10.png.
#
# Processing image 11/2249: 04_29_19_page_11.png (Label: single column)
#   Detected 4 final regions for 04_29_19_page_11.png.
#
# Processing image 12/2249: 04_29_19_page_12.png (Label: single column)
#   Detected 4 final regions for 04_29_19_page_12.png.
#
# Processing image 13/2249: 04_29_19_page_13.png (Label: single column)
#   Detected 4 final regions for 04_29_19_page_13.png.
#
# Processing image 14/2249: 04_29_19_page_14.png (Label: single column)
#   Detected 4 final regions for 04_29_19_page_14.png.
#
# Processing image 15/2249: 04_29_19_page_15.png (Label: single column)
#   Detected 4 final regions for 04_29_19_page_15.png.
#
# Processing image 16/2249: 04_29_19_page_16.png (Label: single column)
#   Detected 4 final regions for 04_29_19_page_16.png.
#
# Processing image 17/2249: 04_29_19_page_17.png (Label: single column)
#   Detected 4 final regions for 04_29_19_page_17.png.
#
# Processing image 18/2249: 04_29_19_page_18.png (Label: single column)
#   Detected 4 final regions for 04_29_19_page_18.png.
#
# Processing image 19/2249: 04_29_19_page_19.png (Label: single column)
#   Detected 4 final regions for 04_29_19_page_19.png.
#
# Processing image 20/2249: 04_29_19_page_20.png (Label: single column)
#   Detected 4 final regions for 04_29_19_page_20.png.
#
# Processing image 21/2249: 04_29_19_page_21.png (Label: single column)
#   Detected 4 final regions for 04_29_19_page_21.png.
#
# Processing image 22/2249: 04_29_19_page_22.png (Label: single column)
#   Detected 4 final regions for 04_29_19_page_22.png.
#
# Processing image 23/2249: 04_29_19_page_23.png (Label: single column)
#   Detected 4 final regions for 04_29_19_page_23.png.
#
# Processing image 24/2249: 04_29_19_page_24.png (Label: single column)
#   Detected 4 final regions for 04_29_19_page_24.png.
#
# Processing image 25/2249: 04_29_19_page_25.png (Label: single column)
#   Detected 4 final regions for 04_29_19_page_25.png.
#
# Processing image 26/2249: 04_29_19_page_26.png (Label: single column)
#   Detected 4 final regions for 04_29_19_page_26.png.
#
# Processing image 27/2249: 04_29_19_page_27.png (Label: single column)
#   Detected 4 final regions for 04_29_19_page_27.png.
#
# Processing image 28/2249: 04_29_19_page_28.png (Label: single column)
#   Detected 4 final regions for 04_29_19_page_28.png.
#
# Processing image 29/2249: 04_29_19_page_29.png (Label: single column)
#   Detected 4 final regions for 04_29_19_page_29.png.
#
# Processing image 30/2249: 04_29_19_page_30.png (Label: single column)
#   Detected 4 final regions for 04_29_19_page_30.png.
#
# Processing image 31/2249: 04_29_19_page_31.png (Label: single column)
#   Detected 7 final regions for 04_29_19_page_31.png.
#
# Processing image 32/2249: 1706_03762v7_page_1.png (Label: single column)
#   Detected 32 final regions for 1706_03762v7_page_1.png.
#
# Processing image 33/2249: 1706_03762v7_page_2.png (Label: single column)
#   Detected 19 final regions for 1706_03762v7_page_2.png.
#
# Processing image 34/2249: 1706_03762v7_page_3.png (Label: single column)
#   Detected 13 final regions for 1706_03762v7_page_3.png.
#
# Processing image 35/2249: 1706_03762v7_page_4.png (Label: single column)
#   Detected 18 final regions for 1706_03762v7_page_4.png.
#
# Processing image 36/2249: 1706_03762v7_page_5.png (Label: single column)
#   Detected 21 final regions for 1706_03762v7_page_5.png.
#
# Processing image 37/2249: 1706_03762v7_page_6.png (Label: single column)
#   Detected 17 final regions for 1706_03762v7_page_6.png.
#
# Processing image 38/2249: 1706_03762v7_page_7.png (Label: single column)
#   Detected 23 final regions for 1706_03762v7_page_7.png.
#
# Processing image 39/2249: 1706_03762v7_page_8.png (Label: single column)
#   Detected 16 final regions for 1706_03762v7_page_8.png.
#
# Processing image 40/2249: 1706_03762v7_page_9.png (Label: single column)
#   Detected 12 final regions for 1706_03762v7_page_9.png.
#
# Processing image 41/2249: 1706_03762v7_page_10.png (Label: single column)
#   Detected 18 final regions for 1706_03762v7_page_10.png.
#
# Processing image 42/2249: 1706_03762v7_page_11.png (Label: single column)
#   Detected 25 final regions for 1706_03762v7_page_11.png.
#
# Processing image 43/2249: 1706_03762v7_page_12.png (Label: single column)
#   Detected 18 final regions for 1706_03762v7_page_12.png.
#
# Processing image 44/2249: 1706_03762v7_page_13.png (Label: single column)
#   Detected 4 final regions for 1706_03762v7_page_13.png.
#
# Processing image 45/2249: 1706_03762v7_page_14.png (Label: single column)
#   Detected 9 final regions for 1706_03762v7_page_14.png.
#
# Processing image 46/2249: 1706_03762v7_page_15.png (Label: single column)
#   Detected 4 final regions for 1706_03762v7_page_15.png.
#
# Processing image 47/2249: 2210_05189v3_page_1.png (Label: multicolumn)
#   Detected 35 final regions for 2210_05189v3_page_1.png.
#
# Processing image 48/2249: 2210_05189v3_page_2.png (Label: multicolumn)
#   Detected 40 final regions for 2210_05189v3_page_2.png.
#
# Processing image 49/2249: 2210_05189v3_page_3.png (Label: multicolumn)
#   Detected 34 final regions for 2210_05189v3_page_3.png.
#
# Processing image 50/2249: 2210_05189v3_page_4.png (Label: multicolumn)
#   Detected 51 final regions for 2210_05189v3_page_4.png.
#
# Processing image 51/2249: 2210_05189v3_page_5.png (Label: multicolumn)
#   Detected 23 final regions for 2210_05189v3_page_5.png.
#
# Processing image 52/2249: 2210_05189v3_page_6.png (Label: multicolumn)
#   Detected 21 final regions for 2210_05189v3_page_6.png.
#
# Processing image 53/2249: 2210_05189v3_page_7.png (Label: multicolumn)
#   Detected 54 final regions for 2210_05189v3_page_7.png.
#
# Processing image 54/2249: 2210_05189v3_page_8.png (Label: multicolumn)
#   Detected 10 final regions for 2210_05189v3_page_8.png.
#
# Processing image 55/2249: 2303_00747v2_page_1.png (Label: multicolumn)
#   Detected 25 final regions for 2303_00747v2_page_1.png.
#
# Processing image 56/2249: 2303_00747v2_page_2.png (Label: multicolumn)
#   Detected 22 final regions for 2303_00747v2_page_2.png.
#
# Processing image 57/2249: 2303_00747v2_page_3.png (Label: multicolumn)
#   Detected 27 final regions for 2303_00747v2_page_3.png.
#
# Processing image 58/2249: 2303_00747v2_page_4.png (Label: multicolumn)
#   Detected 40 final regions for 2303_00747v2_page_4.png.
#
# Processing image 59/2249: 2303_00747v2_page_5.png (Label: multicolumn)
#   Detected 37 final regions for 2303_00747v2_page_5.png.
#
# Processing image 60/2249: 2303_00747v2_page_6.png (Label: multicolumn)
#   Detected 2 final regions for 2303_00747v2_page_6.png.
#
# Processing image 61/2249: 2402_12354v2_page_1.png (Label: multicolumn)
#   Detected 27 final regions for 2402_12354v2_page_1.png.
#
# Processing image 62/2249: 2402_12354v2_page_2.png (Label: multicolumn)
#   Detected 28 final regions for 2402_12354v2_page_2.png.
#
# Processing image 63/2249: 2402_12354v2_page_3.png (Label: multicolumn)
#   Detected 39 final regions for 2402_12354v2_page_3.png.
#
# Processing image 64/2249: 2402_12354v2_page_4.png (Label: multicolumn)
#   Detected 26 final regions for 2402_12354v2_page_4.png.
#
# Processing image 65/2249: 2402_12354v2_page_5.png (Label: multicolumn)
#   Detected 35 final regions for 2402_12354v2_page_5.png.
#
# Processing image 66/2249: 2402_12354v2_page_6.png (Label: multicolumn)
#   Detected 27 final regions for 2402_12354v2_page_6.png.
#
# Processing image 67/2249: 2402_12354v2_page_7.png (Label: multicolumn)
#   Detected 28 final regions for 2402_12354v2_page_7.png.
#
# Processing image 68/2249: 2402_12354v2_page_8.png (Label: multicolumn)
#   Detected 37 final regions for 2402_12354v2_page_8.png.
#
# Processing image 69/2249: 2402_12354v2_page_9.png (Label: multicolumn)
#   Detected 24 final regions for 2402_12354v2_page_9.png.
#
# Processing image 70/2249: 2402_12354v2_page_10.png (Label: multicolumn)
#   Detected 46 final regions for 2402_12354v2_page_10.png.
#
# Processing image 71/2249: 2402_12354v2_page_11.png (Label: multicolumn)
#   Detected 48 final regions for 2402_12354v2_page_11.png.
#
# Processing image 72/2249: 2402_12354v2_page_12.png (Label: multicolumn)
#   Detected 9 final regions for 2402_12354v2_page_12.png.
#
# Processing image 73/2249: 2402_12354v2_page_13.png (Label: single column)
#   Detected 17 final regions for 2402_12354v2_page_13.png.
#
# Processing image 74/2249: 2402_12354v2_page_14.png (Label: single column)
#   Detected 17 final regions for 2402_12354v2_page_14.png.
#
# Processing image 75/2249: 2402_12354v2_page_15.png (Label: single column)
#   Detected 25 final regions for 2402_12354v2_page_15.png.
#
# Processing image 76/2249: 2402_12354v2_page_16.png (Label: single column)
#   Detected 30 final regions for 2402_12354v2_page_16.png.
#
# Processing image 77/2249: 2402_12354v2_page_17.png (Label: single column)
#   Detected 34 final regions for 2402_12354v2_page_17.png.
#
# Processing image 78/2249: 2402_12354v2_page_18.png (Label: single column)
#   Detected 23 final regions for 2402_12354v2_page_18.png.
#
# Processing image 79/2249: 2402_12354v2_page_19.png (Label: single column)
#   Detected 17 final regions for 2402_12354v2_page_19.png.
#
# Processing image 80/2249: 2402_12354v2_page_20.png (Label: single column)
#   Detected 17 final regions for 2402_12354v2_page_20.png.
#
# Processing image 81/2249: 2402_12354v2_page_21.png (Label: single column)
#   Detected 19 final regions for 2402_12354v2_page_21.png.
#
# Processing image 82/2249: 2402_12354v2_page_22.png (Label: single column)
#   Detected 7 final regions for 2402_12354v2_page_22.png.
#
# Processing image 83/2249: 2402_12354v2_page_23.png (Label: single column)
#   Detected 12 final regions for 2402_12354v2_page_23.png.
#
# Processing image 84/2249: 2402_12354v2_page_24.png (Label: single column)
#   Detected 8 final regions for 2402_12354v2_page_24.png.
#
# Processing image 85/2249: 2409_18594v1_page_1.png (Label: multicolumn)
#   Detected 29 final regions for 2409_18594v1_page_1.png.
#
# Processing image 86/2249: 2409_18594v1_page_2.png (Label: multicolumn)
#   Detected 26 final regions for 2409_18594v1_page_2.png.
#
# Processing image 87/2249: 2409_18594v1_page_3.png (Label: multicolumn)
#   Detected 25 final regions for 2409_18594v1_page_3.png.
#
# Processing image 88/2249: 2409_18594v1_page_4.png (Label: multicolumn)
#   Detected 133 final regions for 2409_18594v1_page_4.png.
#
# Processing image 89/2249: 2409_18594v1_page_5.png (Label: multicolumn)
#   Detected 23 final regions for 2409_18594v1_page_5.png.
#
# Processing image 90/2249: 2409_18594v1_page_6.png (Label: multicolumn)
#   Detected 215 final regions for 2409_18594v1_page_6.png.
#
# Processing image 91/2249: 2409_18594v1_page_7.png (Label: multicolumn)
#   Detected 16 final regions for 2409_18594v1_page_7.png.
#
# Processing image 92/2249: 2409_18594v1_page_8.png (Label: multicolumn)
#   Detected 33 final regions for 2409_18594v1_page_8.png.
#
# Processing image 93/2249: 2409_18594v1_page_9.png (Label: multicolumn)
#   Detected 46 final regions for 2409_18594v1_page_9.png.
#
# Processing image 94/2249: 2409_18594v1_page_10.png (Label: multicolumn)
#   Detected 35 final regions for 2409_18594v1_page_10.png.
#
# Processing image 95/2249: 2409_18594v1_page_11.png (Label: multicolumn)
#   Detected 5 final regions for 2409_18594v1_page_11.png.
#
# Processing image 96/2249: 2409_18594v1_page_12.png (Label: multicolumn)
#   Detected 29 final regions for 2409_18594v1_page_12.png.
#
# Processing image 97/2249: 2409_18594v1_page_13.png (Label: multicolumn)
#   Detected 117 final regions for 2409_18594v1_page_13.png.
#
# Processing image 98/2249: 2409_18594v1_page_14.png (Label: multicolumn)
#   Detected 131 final regions for 2409_18594v1_page_14.png.
#
# Processing image 99/2249: 2409_18594v1_page_15.png (Label: multicolumn)
#   Detected 210 final regions for 2409_18594v1_page_15.png.
#
# Processing image 100/2249: 2409_18594v1_page_16.png (Label: multicolumn)
#   Detected 13 final regions for 2409_18594v1_page_16.png.
#
# Processing image 101/2249: 2409_18594v1_page_17.png (Label: multicolumn)
#   Detected 5 final regions for 2409_18594v1_page_17.png.
#
# Processing image 102/2249: 2409_18594v1_page_18.png (Label: multicolumn)
#   Detected 7 final regions for 2409_18594v1_page_18.png.
#
# Processing image 103/2249: 2409_18594v1_page_19.png (Label: multicolumn)
#   Detected 136 final regions for 2409_18594v1_page_19.png.
#
# Processing image 104/2249: 2409_18594v1_page_20.png (Label: multicolumn)
#   Detected 94 final regions for 2409_18594v1_page_20.png.
#
# Processing image 105/2249: 2409_18594v1_page_21.png (Label: multicolumn)
#   Detected 37 final regions for 2409_18594v1_page_21.png.
#
# Processing image 106/2249: 2412_05270v4_page_1.png (Label: multicolumn)
#   Detected 24 final regions for 2412_05270v4_page_1.png.
#
# Processing image 107/2249: 2412_05270v4_page_2.png (Label: multicolumn)
#   Detected 19 final regions for 2412_05270v4_page_2.png.
#
# Processing image 108/2249: 2412_05270v4_page_3.png (Label: multicolumn)
#   Detected 35 final regions for 2412_05270v4_page_3.png.
#
# Processing image 109/2249: 2412_05270v4_page_4.png (Label: multicolumn)
#   Detected 40 final regions for 2412_05270v4_page_4.png.
#
# Processing image 110/2249: 2412_05270v4_page_5.png (Label: multicolumn)
#   Detected 36 final regions for 2412_05270v4_page_5.png.
#
# Processing image 111/2249: 2412_05270v4_page_6.png (Label: multicolumn)
#   Detected 40 final regions for 2412_05270v4_page_6.png.
#
# Processing image 112/2249: 2412_05270v4_page_7.png (Label: multicolumn)
#   Detected 29 final regions for 2412_05270v4_page_7.png.
#
# Processing image 113/2249: 2412_05270v4_page_8.png (Label: multicolumn)
#   Detected 32 final regions for 2412_05270v4_page_8.png.
#
# Processing image 114/2249: 2412_05270v4_page_9.png (Label: multicolumn)
#   Detected 12 final regions for 2412_05270v4_page_9.png.
#
# Processing image 115/2249: 2412_05270v4_page_10.png (Label: multicolumn)
#   Detected 29 final regions for 2412_05270v4_page_10.png.
#
# Processing image 116/2249: 2412_05270v4_page_11.png (Label: multicolumn)
#   Detected 18 final regions for 2412_05270v4_page_11.png.
#
# Processing image 117/2249: 2412_05270v4_page_12.png (Label: multicolumn)
#   Detected 18 final regions for 2412_05270v4_page_12.png.
#
# Processing image 118/2249: 2412_05270v4_page_13.png (Label: multicolumn)
#   Detected 23 final regions for 2412_05270v4_page_13.png.
#
# Processing image 119/2249: 2412_05270v4_page_14.png (Label: multicolumn)
#   Detected 28 final regions for 2412_05270v4_page_14.png.
#
# Processing image 120/2249: 2412_05270v4_page_15.png (Label: multicolumn)
#   Detected 42 final regions for 2412_05270v4_page_15.png.
#
# Processing image 121/2249: 2412_05270v4_page_16.png (Label: multicolumn)
#   Detected 37 final regions for 2412_05270v4_page_16.png.
#
# Processing image 122/2249: 2412_05270v4_page_17.png (Label: multicolumn)
#   Detected 37 final regions for 2412_05270v4_page_17.png.
#
# Processing image 123/2249: 2412_05270v4_page_18.png (Label: multicolumn)
#   Detected 60 final regions for 2412_05270v4_page_18.png.
#
# Processing image 124/2249: 2412_05270v4_page_19.png (Label: multicolumn)
#   Detected 55 final regions for 2412_05270v4_page_19.png.
#
# Processing image 125/2249: 2412_05270v4_page_20.png (Label: multicolumn)
#   Detected 50 final regions for 2412_05270v4_page_20.png.
#
# Processing image 126/2249: 2412_05270v4_page_21.png (Label: multicolumn)
#   Detected 48 final regions for 2412_05270v4_page_21.png.
#
# Processing image 127/2249: 2412_05270v4_page_22.png (Label: multicolumn)
#   Detected 24 final regions for 2412_05270v4_page_22.png.
#
# Processing image 128/2249: 2412_05270v4_page_23.png (Label: multicolumn)
#   Detected 8 final regions for 2412_05270v4_page_23.png.
#
# Processing image 129/2249: 2412_05270v4_page_24.png (Label: multicolumn)
#   Detected 71 final regions for 2412_05270v4_page_24.png.
#
# Processing image 130/2249: 2504_01848v3_page_1.png (Label: multicolumn)
#   Detected 31 final regions for 2504_01848v3_page_1.png.
#
# Processing image 131/2249: 2504_01848v3_page_2.png (Label: multicolumn)
#   Detected 18 final regions for 2504_01848v3_page_2.png.
#
# Processing image 132/2249: 2504_01848v3_page_3.png (Label: multicolumn)
#   Detected 31 final regions for 2504_01848v3_page_3.png.
#
# Processing image 133/2249: 2504_01848v3_page_4.png (Label: multicolumn)
#   Detected 52 final regions for 2504_01848v3_page_4.png.
#
# Processing image 134/2249: 2504_01848v3_page_5.png (Label: multicolumn)
#   Detected 21 final regions for 2504_01848v3_page_5.png.
#
# Processing image 135/2249: 2504_01848v3_page_6.png (Label: multicolumn)
#   Detected 70 final regions for 2504_01848v3_page_6.png.
#
# Processing image 136/2249: 2504_01848v3_page_7.png (Label: multicolumn)
#   Detected 65 final regions for 2504_01848v3_page_7.png.
#
# Processing image 137/2249: 2504_01848v3_page_8.png (Label: multicolumn)
#   Detected 22 final regions for 2504_01848v3_page_8.png.
#
# Processing image 138/2249: 2504_01848v3_page_9.png (Label: multicolumn)
#   Detected 29 final regions for 2504_01848v3_page_9.png.
#
# Processing image 139/2249: 2504_01848v3_page_10.png (Label: multicolumn)
#   Detected 32 final regions for 2504_01848v3_page_10.png.
#
# Processing image 140/2249: 2504_01848v3_page_11.png (Label: multicolumn)
#   Detected 53 final regions for 2504_01848v3_page_11.png.
#
# Processing image 141/2249: 2504_01848v3_page_12.png (Label: multicolumn)
#   Detected 42 final regions for 2504_01848v3_page_12.png.
#
# Processing image 142/2249: 2504_01848v3_page_13.png (Label: multicolumn)
#   Detected 18 final regions for 2504_01848v3_page_13.png.
#
# Processing image 143/2249: 2504_01848v3_page_14.png (Label: multicolumn)
#   Detected 23 final regions for 2504_01848v3_page_14.png.
#
# Processing image 144/2249: 2504_01848v3_page_15.png (Label: multicolumn)
#   Detected 112 final regions for 2504_01848v3_page_15.png.
#
# Processing image 145/2249: 2504_01848v3_page_16.png (Label: multicolumn)
#   Detected 17 final regions for 2504_01848v3_page_16.png.
#
# Processing image 146/2249: 2504_01848v3_page_17.png (Label: multicolumn)
#   Detected 18 final regions for 2504_01848v3_page_17.png.
#
# Processing image 147/2249: 2504_01848v3_page_18.png (Label: multicolumn)
#   Detected 47 final regions for 2504_01848v3_page_18.png.
#
# Processing image 148/2249: 2504_01848v3_page_19.png (Label: multicolumn)
#   Detected 25 final regions for 2504_01848v3_page_19.png.
#
# Processing image 149/2249: 2504_01848v3_page_20.png (Label: multicolumn)
#   Detected 212 final regions for 2504_01848v3_page_20.png.
#
# Processing image 150/2249: 2504_01848v3_page_21.png (Label: multicolumn)
#   Detected 212 final regions for 2504_01848v3_page_21.png.
#
# Processing image 151/2249: 2504_01848v3_page_22.png (Label: multicolumn)
#   Detected 212 final regions for 2504_01848v3_page_22.png.
#
# Processing image 152/2249: 2504_01848v3_page_23.png (Label: multicolumn)
#   Detected 212 final regions for 2504_01848v3_page_23.png.
#
# Processing image 153/2249: 2504_01848v3_page_24.png (Label: multicolumn)
#   Detected 105 final regions for 2504_01848v3_page_24.png.
#
# Processing image 154/2249: 2504_01848v3_page_25.png (Label: multicolumn)
#   Detected 4 final regions for 2504_01848v3_page_25.png.
#
# Processing image 155/2249: 2504_01848v3_page_26.png (Label: multicolumn)
#   Detected 4 final regions for 2504_01848v3_page_26.png.
#
# Processing image 156/2249: 2504_01848v3_page_27.png (Label: multicolumn)
#   Detected 4 final regions for 2504_01848v3_page_27.png.
#
# Processing image 157/2249: 2504_01848v3_page_28.png (Label: multicolumn)
#   Detected 8 final regions for 2504_01848v3_page_28.png.
#
# Processing image 158/2249: 2504_01848v3_page_29.png (Label: multicolumn)
#   Detected 4 final regions for 2504_01848v3_page_29.png.
#
# Processing image 159/2249: 2504_01848v3_page_30.png (Label: multicolumn)
#   Detected 4 final regions for 2504_01848v3_page_30.png.
#
# Processing image 160/2249: 2504_16072v1_page_1.png (Label: multicolumn)
#   Detected 70 final regions for 2504_16072v1_page_1.png.
#
# Processing image 161/2249: 2504_16072v1_page_2.png (Label: multicolumn)
#   Detected 83 final regions for 2504_16072v1_page_2.png.
#
# Processing image 162/2249: 2504_16072v1_page_3.png (Label: multicolumn)
#   Detected 83 final regions for 2504_16072v1_page_3.png.
#
# Processing image 163/2249: 2504_16072v1_page_4.png (Label: multicolumn)
#   Detected 64 final regions for 2504_16072v1_page_4.png.
#
# Processing image 164/2249: 2504_16072v1_page_5.png (Label: multicolumn)
#   Detected 91 final regions for 2504_16072v1_page_5.png.
#
# Processing image 165/2249: 2504_16072v1_page_6.png (Label: multicolumn)
#   Detected 92 final regions for 2504_16072v1_page_6.png.
#
# Processing image 166/2249: 2504_16072v1_page_7.png (Label: multicolumn)
#   Detected 49 final regions for 2504_16072v1_page_7.png.
#
# Processing image 167/2249: 2504_16072v1_page_8.png (Label: multicolumn)
#   Detected 71 final regions for 2504_16072v1_page_8.png.
#
# Processing image 168/2249: 2504_16072v1_page_9.png (Label: multicolumn)
#   Detected 56 final regions for 2504_16072v1_page_9.png.
#
# Processing image 169/2249: 2504_16072v1_page_10.png (Label: multicolumn)
#   Detected 33 final regions for 2504_16072v1_page_10.png.
#
# Processing image 170/2249: 2504_16072v1_page_11.png (Label: multicolumn)
#   Detected 94 final regions for 2504_16072v1_page_11.png.
#
# Processing image 171/2249: 2504_16072v1_page_12.png (Label: multicolumn)
#   Detected 48 final regions for 2504_16072v1_page_12.png.
#
# Processing image 172/2249: 2504_16072v1_page_13.png (Label: multicolumn)
#   Detected 73 final regions for 2504_16072v1_page_13.png.
#
# Processing image 173/2249: 2504_16072v1_page_14.png (Label: multicolumn)
#   Detected 74 final regions for 2504_16072v1_page_14.png.
#
# Processing image 174/2249: 2504_16072v1_page_15.png (Label: multicolumn)
#   Detected 50 final regions for 2504_16072v1_page_15.png.
#
# Processing image 175/2249: 2504_16072v1_page_16.png (Label: multicolumn)
#   Detected 92 final regions for 2504_16072v1_page_16.png.
#
# Processing image 176/2249: 2504_16072v1_page_17.png (Label: multicolumn)
#   Detected 54 final regions for 2504_16072v1_page_17.png.
#
# Processing image 177/2249: 2504_16072v1_page_18.png (Label: multicolumn)
#   Detected 92 final regions for 2504_16072v1_page_18.png.
#
# Processing image 178/2249: 2504_16072v1_page_19.png (Label: multicolumn)
#   Detected 57 final regions for 2504_16072v1_page_19.png.
#
# Processing image 179/2249: 2504_16072v1_page_20.png (Label: multicolumn)
#   Detected 50 final regions for 2504_16072v1_page_20.png.
#
# Processing image 180/2249: 2504_16072v1_page_21.png (Label: multicolumn)
#   Detected 60 final regions for 2504_16072v1_page_21.png.
#
# Processing image 181/2249: 2504_16072v1_page_22.png (Label: multicolumn)
#   Detected 25 final regions for 2504_16072v1_page_22.png.
#
# Processing image 182/2249: 2504_16072v1_page_23.png (Label: multicolumn)
#   Detected 34 final regions for 2504_16072v1_page_23.png.
#
# Processing image 183/2249: 2504_16072v1_page_24.png (Label: multicolumn)
#   Detected 48 final regions for 2504_16072v1_page_24.png.
#
# Processing image 184/2249: 2504_16072v1_page_25.png (Label: multicolumn)
#   Detected 27 final regions for 2504_16072v1_page_25.png.
#
# Processing image 185/2249: 2504_16072v1_page_26.png (Label: multicolumn)
#   Detected 78 final regions for 2504_16072v1_page_26.png.
#
# Processing image 186/2249: 2504_16072v1_page_27.png (Label: multicolumn)
#   Detected 88 final regions for 2504_16072v1_page_27.png.
#
# Processing image 187/2249: 2504_16072v1_page_28.png (Label: multicolumn)
#   Detected 102 final regions for 2504_16072v1_page_28.png.
#
# Processing image 188/2249: 2504_16072v1_page_29.png (Label: multicolumn)
#   Detected 101 final regions for 2504_16072v1_page_29.png.
#
# Processing image 189/2249: 2504_16072v1_page_30.png (Label: multicolumn)
#   Detected 101 final regions for 2504_16072v1_page_30.png.
#
# Processing image 190/2249: 2504_16072v1_page_31.png (Label: multicolumn)
#   Detected 96 final regions for 2504_16072v1_page_31.png.
#
# Processing image 191/2249: 2504_16072v1_page_32.png (Label: multicolumn)
#   Detected 80 final regions for 2504_16072v1_page_32.png.
#
# Processing image 192/2249: 2504_19944v1_page_1.png (Label: single column)
#   Detected 44 final regions for 2504_19944v1_page_1.png.
#
# Processing image 193/2249: 2504_19944v1_page_2.png (Label: single column)
#   Detected 10 final regions for 2504_19944v1_page_2.png.
#
# Processing image 194/2249: 2504_19944v1_page_3.png (Label: single column)
#   Detected 14 final regions for 2504_19944v1_page_3.png.
#
# Processing image 195/2249: 2504_19944v1_page_4.png (Label: single column)
#   Detected 14 final regions for 2504_19944v1_page_4.png.
#
# Processing image 196/2249: 2504_19944v1_page_5.png (Label: single column)
#   Detected 16 final regions for 2504_19944v1_page_5.png.
#
# Processing image 197/2249: 2504_19944v1_page_6.png (Label: single column)
#   Detected 11 final regions for 2504_19944v1_page_6.png.
#
# Processing image 198/2249: 2504_19944v1_page_7.png (Label: single column)
#   Detected 13 final regions for 2504_19944v1_page_7.png.
#
# Processing image 199/2249: 2504_19944v1_page_8.png (Label: single column)
#   Detected 40 final regions for 2504_19944v1_page_8.png.
#
# Processing image 200/2249: 2504_19944v1_page_9.png (Label: single column)
#   Detected 17 final regions for 2504_19944v1_page_9.png.
#
# Processing image 201/2249: 2504_19944v1_page_10.png (Label: single column)
#   Detected 13 final regions for 2504_19944v1_page_10.png.
#
# Processing image 202/2249: 2504_19944v1_page_11.png (Label: single column)
#   Detected 17 final regions for 2504_19944v1_page_11.png.
#
# Processing image 203/2249: 2504_19944v1_page_12.png (Label: single column)
#   Detected 12 final regions for 2504_19944v1_page_12.png.
#
# Processing image 204/2249: 2504_19944v1_page_13.png (Label: single column)
#   Detected 13 final regions for 2504_19944v1_page_13.png.
#
# Processing image 205/2249: 2504_19944v1_page_14.png (Label: single column)
#   Detected 19 final regions for 2504_19944v1_page_14.png.
#
# Processing image 206/2249: 2504_19944v1_page_15.png (Label: single column)
#   Detected 18 final regions for 2504_19944v1_page_15.png.
#
# Processing image 207/2249: 2504_19944v1_page_16.png (Label: single column)
#   Detected 23 final regions for 2504_19944v1_page_16.png.
#
# Processing image 208/2249: 2504_19944v1_page_17.png (Label: single column)
#   Detected 23 final regions for 2504_19944v1_page_17.png.
#
# Processing image 209/2249: 2504_19944v1_page_18.png (Label: single column)
#   Detected 22 final regions for 2504_19944v1_page_18.png.
#
# Processing image 210/2249: 2504_19944v1_page_19.png (Label: single column)
#   Detected 17 final regions for 2504_19944v1_page_19.png.
#
# Processing image 211/2249: 2504_19944v1_page_20.png (Label: single column)
#   Detected 12 final regions for 2504_19944v1_page_20.png.
#
# Processing image 212/2249: 2504_19944v1_page_21.png (Label: single column)
#   Detected 5 final regions for 2504_19944v1_page_21.png.
#
# Processing image 213/2249: 2504_19944v1_page_22.png (Label: single column)
#   Detected 17 final regions for 2504_19944v1_page_22.png.
#
# Processing image 214/2249: 2504_19944v1_page_23.png (Label: single column)
#   Detected 18 final regions for 2504_19944v1_page_23.png.
#
# Processing image 215/2249: 2504_19944v1_page_24.png (Label: single column)
#   Detected 4 final regions for 2504_19944v1_page_24.png.
#
# Processing image 216/2249: 2504_19944v1_page_25.png (Label: single column)
#   Detected 34 final regions for 2504_19944v1_page_25.png.
#
# Processing image 217/2249: 2504_19944v1_page_26.png (Label: single column)
#   Detected 19 final regions for 2504_19944v1_page_26.png.
#
# Processing image 218/2249: 2504_19944v1_page_27.png (Label: single column)
#   Detected 21 final regions for 2504_19944v1_page_27.png.
#
# Processing image 219/2249: 2504_19944v1_page_28.png (Label: single column)
#   Detected 26 final regions for 2504_19944v1_page_28.png.
#
# Processing image 220/2249: 2504_19944v1_page_29.png (Label: single column)
#   Detected 4 final regions for 2504_19944v1_page_29.png.
#
# Processing image 221/2249: 2504_19944v1_page_30.png (Label: single column)
#   Detected 4 final regions for 2504_19944v1_page_30.png.
#
# Processing image 222/2249: 2504_19944v1_page_31.png (Label: single column)
#   Detected 10 final regions for 2504_19944v1_page_31.png.
#
# Processing image 223/2249: 2504_19950v1_page_1.png (Label: multicolumn)
#   Detected 30 final regions for 2504_19950v1_page_1.png.
#
# Processing image 224/2249: 2504_19950v1_page_2.png (Label: multicolumn)
#   Detected 32 final regions for 2504_19950v1_page_2.png.
#
# Processing image 225/2249: 2504_19950v1_page_3.png (Label: multicolumn)
#   Detected 52 final regions for 2504_19950v1_page_3.png.
#
# Processing image 226/2249: 2504_19950v1_page_4.png (Label: multicolumn)
#   Detected 61 final regions for 2504_19950v1_page_4.png.
#
# Processing image 227/2249: 2504_19950v1_page_5.png (Label: multicolumn)
#   Detected 65 final regions for 2504_19950v1_page_5.png.
#
# Processing image 228/2249: 2504_19950v1_page_6.png (Label: multicolumn)
#   Detected 61 final regions for 2504_19950v1_page_6.png.
#
# Processing image 229/2249: 2504_19950v1_page_7.png (Label: multicolumn)
#   Detected 57 final regions for 2504_19950v1_page_7.png.
#
# Processing image 230/2249: 2504_19950v1_page_8.png (Label: multicolumn)
#   Detected 77 final regions for 2504_19950v1_page_8.png.
#
# Processing image 231/2249: 2504_19950v1_page_9.png (Label: multicolumn)
#   Detected 58 final regions for 2504_19950v1_page_9.png.
#
# Processing image 232/2249: 2504_19950v1_page_10.png (Label: multicolumn)
#   Detected 54 final regions for 2504_19950v1_page_10.png.
#
# Processing image 233/2249: 2504_19950v1_page_11.png (Label: multicolumn)
#   Detected 32 final regions for 2504_19950v1_page_11.png.
#
# Processing image 234/2249: 2504_19950v1_page_12.png (Label: multicolumn)
#   Detected 27 final regions for 2504_19950v1_page_12.png.
#
# Processing image 235/2249: 2504_19950v1_page_13.png (Label: multicolumn)
#   Detected 19 final regions for 2504_19950v1_page_13.png.
#
# Processing image 236/2249: 2504_19950v1_page_14.png (Label: multicolumn)
#   Detected 7 final regions for 2504_19950v1_page_14.png.
#
# Processing image 237/2249: 2504_19955v1_page_1.png (Label: multicolumn)
#   Detected 38 final regions for 2504_19955v1_page_1.png.
#
# Processing image 238/2249: 2504_19955v1_page_2.png (Label: multicolumn)
#   Detected 25 final regions for 2504_19955v1_page_2.png.
#
# Processing image 239/2249: 2504_19955v1_page_3.png (Label: multicolumn)
#   Detected 30 final regions for 2504_19955v1_page_3.png.
#
# Processing image 240/2249: 2504_19955v1_page_4.png (Label: multicolumn)
#   Detected 38 final regions for 2504_19955v1_page_4.png.
#
# Processing image 241/2249: 2504_19955v1_page_5.png (Label: multicolumn)
#   Detected 38 final regions for 2504_19955v1_page_5.png.
#
# Processing image 242/2249: 2504_19955v1_page_6.png (Label: multicolumn)
#   Detected 34 final regions for 2504_19955v1_page_6.png.
#
# Processing image 243/2249: 2504_19997v1_page_1.png (Label: multicolumn)
#   Detected 30 final regions for 2504_19997v1_page_1.png.
#
# Processing image 244/2249: 2504_19997v1_page_2.png (Label: multicolumn)
#   Detected 32 final regions for 2504_19997v1_page_2.png.
#
# Processing image 245/2249: 2504_19997v1_page_3.png (Label: multicolumn)
#   Detected 25 final regions for 2504_19997v1_page_3.png.
#
# Processing image 246/2249: 2504_19997v1_page_4.png (Label: multicolumn)
#   Detected 34 final regions for 2504_19997v1_page_4.png.
#
# Processing image 247/2249: 2504_20018v1_page_1.png (Label: multicolumn)
#   Detected 34 final regions for 2504_20018v1_page_1.png.
#
# Processing image 248/2249: 2504_20018v1_page_2.png (Label: multicolumn)
#   Detected 29 final regions for 2504_20018v1_page_2.png.
#
# Processing image 249/2249: 2504_20018v1_page_3.png (Label: multicolumn)
#   Detected 34 final regions for 2504_20018v1_page_3.png.
#
# Processing image 250/2249: 2504_20018v1_page_4.png (Label: multicolumn)
#   Detected 33 final regions for 2504_20018v1_page_4.png.
#
# Processing image 251/2249: 2504_20018v1_page_5.png (Label: multicolumn)
#   Detected 27 final regions for 2504_20018v1_page_5.png.
#
# Processing image 252/2249: 2504_20018v1_page_6.png (Label: multicolumn)
#   Detected 22 final regions for 2504_20018v1_page_6.png.
#
# Processing image 253/2249: 2504_20018v1_page_7.png (Label: multicolumn)
#   Detected 51 final regions for 2504_20018v1_page_7.png.
#
# Processing image 254/2249: 2504_20018v1_page_8.png (Label: multicolumn)
#   Detected 30 final regions for 2504_20018v1_page_8.png.
#
# Processing image 255/2249: 2504_20018v1_page_9.png (Label: multicolumn)
#   Detected 51 final regions for 2504_20018v1_page_9.png.
#
# Processing image 256/2249: 2504_20018v1_page_10.png (Label: multicolumn)
#   Detected 27 final regions for 2504_20018v1_page_10.png.
#
# Processing image 257/2249: 2504_20018v1_page_11.png (Label: multicolumn)
#   Detected 27 final regions for 2504_20018v1_page_11.png.
#
# Processing image 258/2249: 2504_20018v1_page_12.png (Label: multicolumn)
#   Detected 20 final regions for 2504_20018v1_page_12.png.
#
# Processing image 259/2249: 2504_20018v1_page_13.png (Label: multicolumn)
#   Detected 5 final regions for 2504_20018v1_page_13.png.
#
# Processing image 260/2249: 2504_20018v1_page_14.png (Label: multicolumn)
#   Detected 6 final regions for 2504_20018v1_page_14.png.
#
# Processing image 261/2249: 2504_20026v1_page_1.png (Label: multicolumn)
#   Detected 23 final regions for 2504_20026v1_page_1.png.
#
# Processing image 262/2249: 2504_20026v1_page_2.png (Label: multicolumn)
#   Detected 12 final regions for 2504_20026v1_page_2.png.
#
# Processing image 263/2249: 2504_20026v1_page_3.png (Label: multicolumn)
#   Detected 37 final regions for 2504_20026v1_page_3.png.
#
# Processing image 264/2249: 2504_20026v1_page_4.png (Label: multicolumn)
#   Detected 49 final regions for 2504_20026v1_page_4.png.
#
# Processing image 265/2249: 2504_20026v1_page_5.png (Label: multicolumn)
#   Detected 53 final regions for 2504_20026v1_page_5.png.
#
# Processing image 266/2249: 2504_20026v1_page_6.png (Label: multicolumn)
#   Detected 64 final regions for 2504_20026v1_page_6.png.
#
# Processing image 267/2249: 2504_20026v1_page_7.png (Label: multicolumn)
#   Detected 27 final regions for 2504_20026v1_page_7.png.
#
# Processing image 268/2249: 2504_20026v1_page_8.png (Label: multicolumn)
#   Detected 17 final regions for 2504_20026v1_page_8.png.
#
# Processing image 269/2249: 2504_20026v1_page_9.png (Label: multicolumn)
#   Detected 25 final regions for 2504_20026v1_page_9.png.
#
# Processing image 270/2249: 2504_20026v1_page_10.png (Label: multicolumn)
#   Detected 45 final regions for 2504_20026v1_page_10.png.
#
# Processing image 271/2249: 2504_20026v1_page_11.png (Label: multicolumn)
#   Detected 37 final regions for 2504_20026v1_page_11.png.
#
# Processing image 272/2249: 2504_20026v1_page_12.png (Label: multicolumn)
#   Detected 34 final regions for 2504_20026v1_page_12.png.
#
# Processing image 273/2249: 2504_20026v1_page_13.png (Label: multicolumn)
#   Detected 33 final regions for 2504_20026v1_page_13.png.
#
# Processing image 274/2249: 2504_20026v1_page_14.png (Label: multicolumn)
#   Detected 27 final regions for 2504_20026v1_page_14.png.
#
# Processing image 275/2249: 2504_20026v1_page_15.png (Label: multicolumn)
#   Detected 29 final regions for 2504_20026v1_page_15.png.
#
# Processing image 276/2249: 2504_20026v1_page_16.png (Label: multicolumn)
#   Detected 30 final regions for 2504_20026v1_page_16.png.
#
# Processing image 277/2249: 2504_20026v1_page_17.png (Label: multicolumn)
#   Detected 47 final regions for 2504_20026v1_page_17.png.
#
# Processing image 278/2249: 2504_20026v1_page_18.png (Label: multicolumn)
#   Detected 12 final regions for 2504_20026v1_page_18.png.
#
# Processing image 279/2249: 2504_20041v1_page_1.png (Label: multicolumn)
#   Detected 23 final regions for 2504_20041v1_page_1.png.
#
# Processing image 280/2249: 2504_20041v1_page_2.png (Label: multicolumn)
#   Detected 19 final regions for 2504_20041v1_page_2.png.
#
# Processing image 281/2249: 2504_20041v1_page_3.png (Label: multicolumn)
#   Detected 31 final regions for 2504_20041v1_page_3.png.
#
# Processing image 282/2249: 2504_20041v1_page_4.png (Label: multicolumn)
#   Detected 35 final regions for 2504_20041v1_page_4.png.
#
# Processing image 283/2249: 2504_20041v1_page_5.png (Label: multicolumn)
#   Detected 25 final regions for 2504_20041v1_page_5.png.
#
# Processing image 284/2249: 2504_20041v1_page_6.png (Label: multicolumn)
#   Detected 41 final regions for 2504_20041v1_page_6.png.
#
# Processing image 285/2249: 2504_20041v1_page_7.png (Label: multicolumn)
#   Detected 100 final regions for 2504_20041v1_page_7.png.
#
# Processing image 286/2249: 2504_20041v1_page_8.png (Label: multicolumn)
#   Detected 102 final regions for 2504_20041v1_page_8.png.
#
# Processing image 287/2249: 2504_20041v1_page_9.png (Label: multicolumn)
#   Detected 43 final regions for 2504_20041v1_page_9.png.
#
# Processing image 288/2249: 2504_20041v1_page_10.png (Label: multicolumn)
#   Detected 47 final regions for 2504_20041v1_page_10.png.
#
# Processing image 289/2249: 2504_20041v1_page_11.png (Label: multicolumn)
#   Detected 44 final regions for 2504_20041v1_page_11.png.
#
# Processing image 290/2249: 2504_20041v1_page_12.png (Label: multicolumn)
#   Detected 39 final regions for 2504_20041v1_page_12.png.
#
# Processing image 291/2249: 2504_20041v1_page_13.png (Label: multicolumn)
#   Detected 16 final regions for 2504_20041v1_page_13.png.
#
# Processing image 292/2249: 2504_20041v1_page_14.png (Label: multicolumn)
#   Detected 16 final regions for 2504_20041v1_page_14.png.
#
# Processing image 293/2249: Finn_page_1.png (Label: single column)
#   Detected 14 final regions for Finn_page_1.png.
#
# Processing image 294/2249: Finn_page_2.png (Label: single column)
#   Detected 11 final regions for Finn_page_2.png.
#
# Processing image 295/2249: Finn_page_3.png (Label: single column)
#   Detected 15 final regions for Finn_page_3.png.
#
# Processing image 296/2249: Finn_page_4.png (Label: single column)
#   Detected 18 final regions for Finn_page_4.png.
#
# Processing image 297/2249: Finn_page_5.png (Label: single column)
#   Detected 18 final regions for Finn_page_5.png.
#
# Processing image 298/2249: Finn_page_6.png (Label: single column)
#   Detected 15 final regions for Finn_page_6.png.
#
# Processing image 299/2249: Finn_page_7.png (Label: single column)
#   Detected 16 final regions for Finn_page_7.png.
#
# Processing image 300/2249: Finn_page_8.png (Label: single column)
#   Detected 8 final regions for Finn_page_8.png.
#
# Processing image 301/2249: Finn_page_9.png (Label: single column)
#   Detected 7 final regions for Finn_page_9.png.
#
# Processing image 302/2249: Finn_page_10.png (Label: single column)
#   Detected 16 final regions for Finn_page_10.png.
#
# Processing image 303/2249: Finn_page_11.png (Label: single column)
#   Detected 14 final regions for Finn_page_11.png.
#
# Processing image 304/2249: Finn_page_12.png (Label: single column)
#   Detected 19 final regions for Finn_page_12.png.
#
# Processing image 305/2249: Finn_page_13.png (Label: single column)
#   Detected 19 final regions for Finn_page_13.png.
#
# Processing image 306/2249: Finn_page_14.png (Label: single column)
#   Detected 18 final regions for Finn_page_14.png.
#
# Processing image 307/2249: Finn_page_15.png (Label: single column)
#   Detected 16 final regions for Finn_page_15.png.
#
# Processing image 308/2249: Finn_page_16.png (Label: single column)
#   Detected 15 final regions for Finn_page_16.png.
#
# Processing image 309/2249: Finn_page_17.png (Label: single column)
#   Detected 15 final regions for Finn_page_17.png.
#
# Processing image 310/2249: Finn_page_18.png (Label: single column)
#   Detected 4 final regions for Finn_page_18.png.
#
# Processing image 311/2249: Finn_page_19.png (Label: single column)
#   Detected 16 final regions for Finn_page_19.png.
#
# Processing image 312/2249: Finn_page_20.png (Label: single column)
#   Detected 16 final regions for Finn_page_20.png.
#
# Processing image 313/2249: Finn_page_21.png (Label: single column)
#   Detected 4 final regions for Finn_page_21.png.
#
# Processing image 314/2249: Finn_page_22.png (Label: single column)
#   Detected 16 final regions for Finn_page_22.png.
#
# Processing image 315/2249: Finn_page_23.png (Label: single column)
#   Detected 18 final regions for Finn_page_23.png.
#
# Processing image 316/2249: Finn_page_24.png (Label: single column)
#   Detected 5 final regions for Finn_page_24.png.
#
# Processing image 317/2249: Finn_page_25.png (Label: single column)
#   Detected 8 final regions for Finn_page_25.png.
#
# Processing image 318/2249: Finn_page_26.png (Label: single column)
#   Detected 21 final regions for Finn_page_26.png.
#
# Processing image 319/2249: Finn_page_27.png (Label: single column)
#   Detected 4 final regions for Finn_page_27.png.
#
# Processing image 320/2249: Finn_page_28.png (Label: single column)
#   Detected 18 final regions for Finn_page_28.png.
#
# Processing image 321/2249: Finn_page_29.png (Label: single column)
#   Detected 16 final regions for Finn_page_29.png.
#
# Processing image 322/2249: Finn_page_30.png (Label: single column)
#   Detected 15 final regions for Finn_page_30.png.
#
# Processing image 323/2249: Gilman_page_2.png (Label: single column)
#   Detected 10 final regions for Gilman_page_2.png.
#
# Processing image 324/2249: Gilman_page_1.png (Label: single column)
#   Detected 19 final regions for Gilman_page_1.png.
#
# Processing image 325/2249: Gilman_page_3.png (Label: single column)
#   Detected 9 final regions for Gilman_page_3.png.
#
# Processing image 326/2249: Gilman_page_4.png (Label: single column)
#   Detected 10 final regions for Gilman_page_4.png.
#
# Processing image 327/2249: Gilman_page_5.png (Label: single column)
#   Detected 11 final regions for Gilman_page_5.png.
#
# Processing image 328/2249: Gilman_page_6.png (Label: single column)
#   Detected 6 final regions for Gilman_page_6.png.
#
# Processing image 329/2249: Gilman_page_7.png (Label: single column)
#   Detected 10 final regions for Gilman_page_7.png.
#
# Processing image 330/2249: Gilman_page_8.png (Label: single column)
#   Detected 7 final regions for Gilman_page_8.png.
#
# Processing image 331/2249: Gilman_page_9.png (Label: single column)
#   Detected 7 final regions for Gilman_page_9.png.
#
# Processing image 332/2249: Gilman_page_10.png (Label: single column)
#   Detected 6 final regions for Gilman_page_10.png.
#
# Processing image 333/2249: Gilman_page_11.png (Label: single column)
#   Detected 6 final regions for Gilman_page_11.png.
#
# Processing image 334/2249: Gilman_page_12.png (Label: single column)
#   Detected 6 final regions for Gilman_page_12.png.
#
# Processing image 335/2249: Gilman_page_13.png (Label: single column)
#   Detected 16 final regions for Gilman_page_13.png.
#
# Processing image 336/2249: Gilman_page_14.png (Label: single column)
#   Detected 7 final regions for Gilman_page_14.png.
#
# Processing image 337/2249: Gilman_page_15.png (Label: single column)
#   Detected 9 final regions for Gilman_page_15.png.
#
# Processing image 338/2249: Gilman_page_16.png (Label: single column)
#   Detected 10 final regions for Gilman_page_16.png.
#
# Processing image 339/2249: Gilman_page_17.png (Label: single column)
#   Detected 9 final regions for Gilman_page_17.png.
#
# Processing image 340/2249: Gilman_page_18.png (Label: single column)
#   Detected 10 final regions for Gilman_page_18.png.
#
# Processing image 341/2249: Gilman_page_19.png (Label: single column)
#   Detected 7 final regions for Gilman_page_19.png.
#
# Processing image 342/2249: Gilman_page_20.png (Label: single column)
#   Detected 8 final regions for Gilman_page_20.png.
#
# Processing image 343/2249: Gilman_page_21.png (Label: single column)
#   Detected 12 final regions for Gilman_page_21.png.
#
# Processing image 344/2249: Gilman_page_22.png (Label: single column)
#   Detected 10 final regions for Gilman_page_22.png.
#
# Processing image 345/2249: Gilman_page_23.png (Label: single column)
#   Detected 7 final regions for Gilman_page_23.png.
#
# Processing image 346/2249: Gilman_page_24.png (Label: single column)
#   Detected 9 final regions for Gilman_page_24.png.
#
# Processing image 347/2249: Hunter_page_1.png (Label: single column)
#   Detected 33 final regions for Hunter_page_1.png.
#
# Processing image 348/2249: Hunter_page_2.png (Label: single column)
#   Detected 20 final regions for Hunter_page_2.png.
#
# Processing image 349/2249: Hunter_page_3.png (Label: single column)
#   Detected 21 final regions for Hunter_page_3.png.
#
# Processing image 350/2249: Hunter_page_4.png (Label: single column)
#   Detected 21 final regions for Hunter_page_4.png.
#
# Processing image 351/2249: Hunter_page_5.png (Label: single column)
#   Detected 29 final regions for Hunter_page_5.png.
#
# Processing image 352/2249: Hunter_page_6.png (Label: single column)
#   Detected 20 final regions for Hunter_page_6.png.
#
# Processing image 353/2249: Hunter_page_7.png (Label: single column)
#   Detected 13 final regions for Hunter_page_7.png.
#
# Processing image 354/2249: Hunter_page_8.png (Label: single column)
#   Detected 20 final regions for Hunter_page_8.png.
#
# Processing image 355/2249: Hunter_page_9.png (Label: single column)
#   Detected 50 final regions for Hunter_page_9.png.
#
# Processing image 356/2249: Hunter_page_10.png (Label: single column)
#   Detected 21 final regions for Hunter_page_10.png.
#
# Processing image 357/2249: Hunter_page_11.png (Label: single column)
#   Detected 24 final regions for Hunter_page_11.png.
#
# Processing image 358/2249: Hunter_page_12.png (Label: single column)
#   Detected 47 final regions for Hunter_page_12.png.
#
# Processing image 359/2249: Hunter_page_13.png (Label: single column)
#   Detected 25 final regions for Hunter_page_13.png.
#
# Processing image 360/2249: Hunter_page_14.png (Label: single column)
#   Detected 47 final regions for Hunter_page_14.png.
#
# Processing image 361/2249: Hunter_page_15.png (Label: single column)
#   Detected 22 final regions for Hunter_page_15.png.
#
# Processing image 362/2249: Hunter_page_16.png (Label: single column)
#   Detected 7 final regions for Hunter_page_16.png.
#
# Processing image 363/2249: Hunter_page_17.png (Label: single column)
#   Detected 50 final regions for Hunter_page_17.png.
#
# Processing image 364/2249: Hunter_page_18.png (Label: single column)
#   Detected 44 final regions for Hunter_page_18.png.
#
# Processing image 365/2249: Hunter_page_19.png (Label: single column)
#   Detected 27 final regions for Hunter_page_19.png.
#
# Processing image 366/2249: Hunter_page_20.png (Label: single column)
#   Detected 21 final regions for Hunter_page_20.png.
#
# Processing image 367/2249: Hunter_page_21.png (Label: single column)
#   Detected 48 final regions for Hunter_page_21.png.
#
# Processing image 368/2249: Hunter_page_22.png (Label: single column)
#   Detected 29 final regions for Hunter_page_22.png.
#
# Processing image 369/2249: Hunter_page_23.png (Label: single column)
#   Detected 15 final regions for Hunter_page_23.png.
#
# Processing image 370/2249: Hunter_page_24.png (Label: single column)
#   Detected 13 final regions for Hunter_page_24.png.
#
# Processing image 371/2249: Hunter_page_25.png (Label: single column)
#   Detected 21 final regions for Hunter_page_25.png.
#
# Processing image 372/2249: Hunter_page_26.png (Label: single column)
#   Detected 47 final regions for Hunter_page_26.png.
#
# Processing image 373/2249: Hunter_page_27.png (Label: single column)
#   Detected 43 final regions for Hunter_page_27.png.
#
# Processing image 374/2249: Hunter_page_28.png (Label: single column)
#   Detected 31 final regions for Hunter_page_28.png.
#
# ...
#
# Processing image 2205/2249: multicolumn_2504_20369v1_page_3.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20369v1_page_3.png. Skipping.
#
# Processing image 2206/2249: multicolumn_2504_20369v1_page_4.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20369v1_page_4.png. Skipping.
#
# Processing image 2207/2249: multicolumn_2504_20369v1_page_5.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20369v1_page_5.png. Skipping.
#
# Processing image 2208/2249: multicolumn_2504_20369v1_page_6.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20369v1_page_6.png. Skipping.
#
# Processing image 2209/2249: multicolumn_2504_20369v1_page_7.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20369v1_page_7.png. Skipping.
#
# Processing image 2210/2249: multicolumn_2504_20369v1_page_8.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20369v1_page_8.png. Skipping.
#
# Processing image 2211/2249: multicolumn_2504_20369v1_page_9.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20369v1_page_9.png. Skipping.
#
# Processing image 2212/2249: multicolumn_2504_20369v1_page_10.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20369v1_page_10.png. Skipping.
#
# Processing image 2213/2249: multicolumn_2504_20369v1_page_11.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20369v1_page_11.png. Skipping.
#
# Processing image 2214/2249: multicolumn_2504_20369v1_page_12.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20369v1_page_12.png. Skipping.
#
# Processing image 2215/2249: multicolumn_2504_20369v1_page_13.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20369v1_page_13.png. Skipping.
#
# Processing image 2216/2249: multicolumn_2504_20369v1_page_14.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20369v1_page_14.png. Skipping.
#
# Processing image 2217/2249: multicolumn_2504_20369v1_page_15.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20369v1_page_15.png. Skipping.
#
# Processing image 2218/2249: multicolumn_2504_20369v1_page_16.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20369v1_page_16.png. Skipping.
#
# Processing image 2219/2249: multicolumn_2504_20369v1_page_17.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20369v1_page_17.png. Skipping.
#
# Processing image 2220/2249: multicolumn_2504_20369v1_page_18.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20369v1_page_18.png. Skipping.
#
# Processing image 2221/2249: multicolumn_2504_20369v1_page_19.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20369v1_page_19.png. Skipping.
#
# Processing image 2222/2249: multicolumn_2504_20768v1_page_1.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20768v1_page_1.png. Skipping.
#
# Processing image 2223/2249: multicolumn_2504_20768v1_page_2.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20768v1_page_2.png. Skipping.
#
# Processing image 2224/2249: multicolumn_2504_20768v1_page_3.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20768v1_page_3.png. Skipping.
#
# Processing image 2225/2249: multicolumn_2504_20768v1_page_4.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20768v1_page_4.png. Skipping.
#
# Processing image 2226/2249: multicolumn_2504_20768v1_page_5.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20768v1_page_5.png. Skipping.
#
# Processing image 2227/2249: multicolumn_2504_20768v1_page_6.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20768v1_page_6.png. Skipping.
#
# Processing image 2228/2249: multicolumn_2504_20768v1_page_7.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20768v1_page_7.png. Skipping.
#
# Processing image 2229/2249: multicolumn_2504_20768v1_page_8.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20768v1_page_8.png. Skipping.
#
# Processing image 2230/2249: multicolumn_2504_20768v1_page_9.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20768v1_page_9.png. Skipping.
#
# Processing image 2231/2249: multicolumn_2504_20768v1_page_10.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20768v1_page_10.png. Skipping.
#
# Processing image 2232/2249: multicolumn_2504_20768v1_page_11.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20768v1_page_11.png. Skipping.
#
# Processing image 2233/2249: multicolumn_2504_20768v1_page_12.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20768v1_page_12.png. Skipping.
#
# Processing image 2234/2249: multicolumn_2504_20768v1_page_13.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20768v1_page_13.png. Skipping.
#
# Processing image 2235/2249: multicolumn_2504_20768v1_page_14.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20768v1_page_14.png. Skipping.
#
# Processing image 2236/2249: multicolumn_2504_20998v1_page_1.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20998v1_page_1.png. Skipping.
#
# Processing image 2237/2249: multicolumn_2504_20998v1_page_2.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20998v1_page_2.png. Skipping.
#
# Processing image 2238/2249: multicolumn_2504_20998v1_page_3.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20998v1_page_3.png. Skipping.
#
# Processing image 2239/2249: multicolumn_2504_20998v1_page_4.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20998v1_page_4.png. Skipping.
#
# Processing image 2240/2249: multicolumn_2504_20998v1_page_5.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20998v1_page_5.png. Skipping.
#
# Processing image 2241/2249: multicolumn_2504_20998v1_page_6.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20998v1_page_6.png. Skipping.
#
# Processing image 2242/2249: multicolumn_2504_20998v1_page_7.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20998v1_page_7.png. Skipping.
#
# Processing image 2243/2249: multicolumn_2504_20998v1_page_8.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20998v1_page_8.png. Skipping.
#
# Processing image 2244/2249: multicolumn_2504_20998v1_page_9.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20998v1_page_9.png. Skipping.
#
# Processing image 2245/2249: multicolumn_2504_20998v1_page_10.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20998v1_page_10.png. Skipping.
#
# Processing image 2246/2249: multicolumn_2504_20998v1_page_11.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20998v1_page_11.png. Skipping.
#
# Processing image 2247/2249: multicolumn_2504_20998v1_page_12.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20998v1_page_12.png. Skipping.
#
# Processing image 2248/2249: multicolumn_2504_20998v1_page_13.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20998v1_page_13.png. Skipping.
#
# Processing image 2249/2249: multicolumn_2504_20998v1_page_14.png (Label: multicolumn)
#   Warning: Image file not found at D:\DATA300\AudioBookSum\src\output_images\multicolumn_2504_20998v1_page_14.png. Skipping.
#
# Features saved to image_layout_features.csv
#
# Data shuffled before splitting.
#
# Labels mapped: {'multicolumn': 0, 'single column': 1}
# Training data shape: (711, 13)
# Testing data shape: (178, 13)
#
# --- KNN Tuning (Accuracy vs. K) ---
# Best K found: 5 with accuracy: 0.9719
# ------------------------------
#
# --- Model Training, Evaluation, and Learning Curves ---
#
# Training Logistic Regression...
#
# --- Logistic Regression Results ---
# Accuracy: 0.9382
# Classification Report:
#                precision    recall  f1-score   support
#
#   multicolumn       0.93      0.94      0.93        79
# single column       0.95      0.94      0.94        99
#
#      accuracy                           0.94       178
#     macro avg       0.94      0.94      0.94       178
#  weighted avg       0.94      0.94      0.94       178
#
# Confusion Matrix:
# Predicted: multicolumn single column
# Actual multicolumn:    [74  5]
# Actual single column:    [ 6 93]
# ---------------------------------
# Generating Learning Curve for Logistic Regression...
# Training K-Nearest Neighbors (K=5)...
#
# --- K-Nearest Neighbors (K=5) Results ---
# Accuracy: 0.9719
# Classification Report:
#                precision    recall  f1-score   support
#
#   multicolumn       0.94      1.00      0.97        79
# single column       1.00      0.95      0.97        99
#
#      accuracy                           0.97       178
#     macro avg       0.97      0.97      0.97       178
#  weighted avg       0.97      0.97      0.97       178
#
# Confusion Matrix:
# Predicted: multicolumn single column
# Actual multicolumn:    [79  0]
# Actual single column:    [ 5 94]
# ---------------------------------------
# Generating Learning Curve for K-Nearest Neighbors (K=5)...
# Training Gaussian Naive Bayes...
#
# --- Gaussian Naive Bayes Results ---
# Accuracy: 0.8427
# Classification Report:
#                precision    recall  f1-score   support
#
#   multicolumn       0.77      0.92      0.84        79
# single column       0.93      0.78      0.85        99
#
#      accuracy                           0.84       178
#     macro avg       0.85      0.85      0.84       178
#  weighted avg       0.86      0.84      0.84       178
#
# Confusion Matrix:
# Predicted: multicolumn single column
# Actual multicolumn:    [73  6]
# Actual single column:    [22 77]
# ----------------------------------
# Generating Learning Curve for Gaussian Naive Bayes...
# Training Decision Tree...
#
# --- Decision Tree Results ---
# Accuracy: 0.9326
# Classification Report:
#                precision    recall  f1-score   support
#
#   multicolumn       0.89      0.97      0.93        79
# single column       0.98      0.90      0.94        99
#
#      accuracy                           0.93       178
#     macro avg       0.93      0.94      0.93       178
#  weighted avg       0.94      0.93      0.93       178
#
# Confusion Matrix:
# Predicted: multicolumn single column
# Actual multicolumn:    [77  2]
# Actual single column:    [10 89]
# ---------------------------
# Generating Learning Curve for Decision Tree...
# Training Random Forest...
#
# --- Random Forest Results ---
# Accuracy: 0.9607
# Classification Report:
#                precision    recall  f1-score   support
#
#   multicolumn       0.93      0.99      0.96        79
# single column       0.99      0.94      0.96        99
#
#      accuracy                           0.96       178
#     macro avg       0.96      0.96      0.96       178
#  weighted avg       0.96      0.96      0.96       178
#
# Confusion Matrix:
# Predicted: multicolumn single column
# Actual multicolumn:    [78  1]
# Actual single column:    [ 6 93]
# ---------------------------
# Generating Learning Curve for Random Forest...
# Training Support Vector Machine (SVM)...
#
# --- Support Vector Machine (SVM) Results ---
# Accuracy: 0.9719
# Classification Report:
#                precision    recall  f1-score   support
#
#   multicolumn       0.96      0.97      0.97        79
# single column       0.98      0.97      0.97        99
#
#      accuracy                           0.97       178
#     macro avg       0.97      0.97      0.97       178
#  weighted avg       0.97      0.97      0.97       178
#
# Confusion Matrix:
# Predicted: multicolumn single column
# Actual multicolumn:    [77  2]
# Actual single column:    [ 3 96]
# ------------------------------------------
# Generating Learning Curve for Support Vector Machine (SVM)...
# Classification comparison complete.
# Best model based on Accuracy: K-Nearest Neighbors (K=5) (0.9719)
# Saved best model to: D:\DATA300\AudioBookSum\src\saved_modelbest_classifier_model.joblib
# Saved feature scaler to: D:\DATA300\AudioBookSum\src\saved_modelfeature_scaler.joblib
# Saved label encoder to: D:\DATA300\AudioBookSum\src\saved_modellabel_encoder.joblib
#
# --- Performance Analysis and Visualization ---
#
# --- Comparative Metrics (Macro Averages) ---
#                        Model  Accuracy  Precision (Macro)  Recall (Macro)  F1-Score (Macro)
#          Logistic Regression  0.938202           0.936990        0.938051          0.937490
#    K-Nearest Neighbors (K=5)  0.971910           0.970238        0.974747          0.971709
#         Gaussian Naive Bayes  0.842697           0.848066        0.850914          0.842617
#                Decision Tree  0.932584           0.931540        0.936837          0.932276
#                Random Forest  0.960674           0.958967        0.963368          0.960393
# Support Vector Machine (SVM)  0.971910           0.971046        0.972190          0.971586
# Using 'K-Nearest Neighbors (K=5)' as baseline for comparison.
#
# --- Performance Difference from Baseline (K-Nearest Neighbors (K=5)) ---
#                        Model Accuracy Diff Precision (Macro) Diff Recall (Macro) Diff F1-Score (Macro) Diff
#          Logistic Regression       -0.0337                -0.0332             -0.0367               -0.0342
#         Gaussian Naive Bayes       -0.1292                -0.1222             -0.1238               -0.1291
#                Decision Tree       -0.0393                -0.0387             -0.0379               -0.0394
#                Random Forest       -0.0112                -0.0113             -0.0114               -0.0113
# Support Vector Machine (SVM)       +0.0000                +0.0008             -0.0026               -0.0001
# Performance difference analysis complete.
#
# --- Loading Model and Running Inference Example ---
# Successfully loaded model, scaler, and encoder.
#
# Example Prediction on first test sample:
#   Predicted Encoded Label: 0
#   Predicted Decoded Label: multicolumn
#   Actual Label: multicolumn (Encoded: 0)

# %%
# --- Function for Single Image Inference ---

def predict_image_layout(image_path: str, model_path: str, scaler_path: str, encoder_path: str) -> Optional[str]:
    """
    Loads a trained model and predicts the layout class for a single image.

    Args:
        image_path: Path to the input image file.
        model_path: Path to the saved classifier model (.joblib).
        scaler_path: Path to the saved feature scaler (.joblib).
        encoder_path: Path to the saved label encoder (.joblib).

    Returns:
        The predicted label string (e.g., 'single_column', 'multi_column') or None if prediction fails.
    """
    print(f"--- Predicting layout for: {os.path.basename(image_path)} ---")

    # 1. Load necessary components
    try:
        model = joblib.load(model_path)
        scaler = joblib.load(scaler_path)
        encoder = joblib.load(encoder_path)
        print("Successfully loaded model, scaler, and encoder.")
    except FileNotFoundError:
        print(f"Error: Could not find one or more required files: {model_path}, {scaler_path}, {encoder_path}")
        return None
    except Exception as e:
        print(f"Error loading model components: {e}")
        return None

    # 2. Process the input image
    if not os.path.exists(image_path):
        print(f"Error: Image file not found at {image_path}")
        return None

    # Extract regions and dimensions (suppress visual proof for single inference)
    boxes, img_w, img_h = extract_regions_from_image(image_path, visual_proof=False)

    if img_w == 0 or img_h == 0:
        print(f"Warning: Could not get valid dimensions or regions for {image_path}. Cannot predict.")
        return None

    # 3. Calculate features
    features_dict = extract_features_from_pixel_boxes(boxes, img_w, img_h)

    # 4. Prepare features for prediction
    # Ensure the feature order matches the training data
    # Get the feature names from the scaler (it remembers the order)
    try:
        # Note: scaler.feature_names_in_ is available in newer scikit-learn versions.
        # If using an older version, you might need to save/load feature names separately.
        feature_names = scaler.get_feature_names_out() # Or scaler.feature_names_in_
    except AttributeError:
         # Fallback: Assume the order in the dictionary is correct, but less robust
         print("Warning: Could not get feature names from scaler. Assuming dictionary order.")
         feature_names = list(features_dict.keys())
         # Remove keys not used as features if they exist in the dict (though they shouldn't based on extract_features)
         feature_names = [f for f in feature_names if f not in ['image_path', 'label']]


    # Create a DataFrame or NumPy array in the correct order
    try:
        features_array = np.array([features_dict.get(name, 0.0) for name in feature_names]).reshape(1, -1)
    except Exception as e:
        print(f"Error preparing feature array: {e}")
        print(f"Feature names expected: {feature_names}")
        print(f"Features extracted: {features_dict.keys()}")
        return None


    # Handle potential NaN/inf values (although fillna(0.0) in extract_features should prevent this)
    features_array = np.nan_to_num(features_array, nan=0.0, posinf=0.0, neginf=0.0)

    # 5. Scale features
    try:
        features_scaled = scaler.transform(features_array)
    except Exception as e:
        print(f"Error scaling features: {e}")
        return None

    # 6. Predict
    try:
        prediction_encoded = model.predict(features_scaled)
    except Exception as e:
        print(f"Error during model prediction: {e}")
        return None

    # 7. Decode prediction
    try:
        prediction_label = encoder.inverse_transform(prediction_encoded)
        print(f"Predicted Encoded Label: {prediction_encoded[0]}")
        print(f"Predicted Decoded Label: {prediction_label[0]}")
        return prediction_label[0]
    except Exception as e:
        print(f"Error decoding prediction: {e}")
        return None

if __name__ == "__main__":

    print("\n--- Running Inference on a New Image ---")

    NEW_IMAGE_PATH = r"D:\path\to\your\new\image.png" 

    # Use the filenames defined earlier when saving
    MODEL_FILE = "best_classifier_model.joblib"
    SCALER_FILE = "feature_scaler.joblib"
    ENCODER_FILE = "label_encoder.joblib"

    # Check if model files exist before attempting prediction
    if os.path.exists(MODEL_FILE) and os.path.exists(SCALER_FILE) and os.path.exists(ENCODER_FILE):
        predicted_class = predict_image_layout(
            image_path=NEW_IMAGE_PATH,
            model_path=MODEL_FILE,
            scaler_path=SCALER_FILE,
            encoder_path=ENCODER_FILE
        )

        if predicted_class:
            print(f"\nFinal Prediction for '{os.path.basename(NEW_IMAGE_PATH)}': {predicted_class}")
        else:
            print(f"\nCould not get a prediction for '{os.path.basename(NEW_IMAGE_PATH)}'.")
    else:
        print("\nSkipping single image inference because model/scaler/encoder files were not found.")
        print("Please ensure the training process ran successfully and saved the files.")
# Out:
# --- Running Inference on a New Image ---
# --- Predicting layout for: image.png ---
# Successfully loaded model, scaler, and encoder.
# Error: Image file not found at D:\path\to\your\new\image.png
#
# Could not get a prediction for 'image.png'.
